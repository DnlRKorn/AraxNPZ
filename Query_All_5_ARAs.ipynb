# %%
import requests
import os.path
import time
import json
import h5py
import pandas as pd
import zipfile
import logging
import multiprocessing as mp
import sys
from time import sleep

# %%
# setting path
sys.path.append('../../PYTHON_SCRIPTS')
import normalize_nodes
#import importlib
#importlib.reload(normalize_nodes)

# %%
logfile = "ara_querying.log"
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
logging.basicConfig(filename=logfile, filemode='a', level=logging.DEBUG, format='%(levelname)s:%(asctime)s %(message)s')

# %%
logging.info("LOGGING STARTED")

# %%
def post_query(url, query_dict):
    try:
        resp = requests.post(url,json=query_dict,timeout=1200)
    except requests.exceptions.ReadTimeout:
        print("Request timed out!")
        logging.warning("Request timed out!")
        return "Error",-1
    except requests.exceptions.ConnectionError:
        print("Request had connection error")
        logging.warning("Request had connection error!")
        return "Error",-1
    print("Query is posted")
    if resp.status_code != 200:
        #return "Error",resp.status_code
        return resp

    return resp

ara_urls = {
    "robokop":"https://aragorn.renci.org/robokop",
    "aragorn":"https://aragorn.renci.org/aragorn",
    "spoke":"https://ia.transltr.io/api/v1.3/",
    "bte":"https://bte.transltr.io/v1",
    "medikanren":"https://medikanren-trapi.transltr.io",
    "arax":"https://arax.ncats.io/api/arax/v1.3"
}

# %%
def get_normalized_for_df(df):
    #df = score_parser(resps[key].json(),None)
    df = normalize_nodes.normalize_data_frame(df,"Disease")
    df = normalize_nodes.normalize_data_frame(df,"Drug")
    return df

def getDfFromResponse(resp,ara=None,disease_idx=None):
    if type(resp)==requests.models.Response:
        if(resp.status_code//100==2):
            resp_json = resp.json()
        else:
            raise ValueError("We didn't get a 2XX code from the server",ara,disease_idx,resp.status_code)
    elif type(resp)==dict:
        resp_json = resp
    return score_parser(resp_json)

# %%
def create_query(callback,disease_id,results=None):
    query_graph = {
            'nodes': {},
            'edges': {}
    }

    query_graph['nodes']['disease'] = {'ids': [disease_id]}
    query_graph['nodes']['chemical'] = {'categories': ['biolink:ChemicalEntity']}
    pnode = 'disease'
    cnode = 'chemical'
    query_graph['edges']['t_edge'] = {'object': pnode, 'subject': cnode, 'predicates':['biolink:treats'], 'knowledge_type': 'inferred'}
    m = {'message':{'query_graph':query_graph}}
    if(callback!=None): m['callback']= callback
    return m

def create_query_for_aragorn(callback,disease_id,results=500):
    m = create_query(callback,disease_id)
    workflow_list = [{"id":"lookup"},
                     {"id":"overlay_connect_knodes"},
                     {"id":"score"},
                     #{"id":"filter_message_top_n","parameters":{"max_results":10}}
                     {"id":"filter_results_top_n","parameters":{"max_results":results}}
                    ]
    m["workflow"] = workflow_list
    return m


def create_query_for_spoke(callback,disease_id,results=10001):
    #query_graph = {
    #        'nodes': {},
    #        'edges': {}
    #}
    #Spoke needs diseases to have a category
    #query_graph['nodes']['disease'] = {'ids': [disease_id], 'categories': ['biolink:Disease']}
    #m['message']['query_graph']['nodes']['disease']['categories'] = ['biolink:Disease']
    #query_graph['nodes']['chemical'] = {'categories': ['biolink:ChemicalEntity']}
    #pnode = 'disease'
    #cnode = 'chemical'
    #query_graph['edges']['t_edge'] = {'object': pnode, 'subject': cnode, 'predicates':['biolink:treats'], 'knowledge_type': 'inferred'}
    #m = {
    #        'message':{'query_graph':query_graph},
    #        'max_results':10}
            
    m = create_query(callback,disease_id)
    #Spoke needs diseases to have a category
    m['message']['query_graph']['nodes']['disease']['categories'] = ['biolink:Disease']
    #query_graph['nodes']['chemical'] = {'categories': ['biolink:ChemicalEntity']}
    m['max_results'] = results
    return m


def create_query_for_arax(callback,disease_id,n_drugs=10):
    query_graph = {
            'nodes': {},
            'edges': {}
    }
    #Spoke needs diseases to have a category
    query_graph['nodes']['disease'] = {'ids': [disease_id], 'categories': ['biolink:Disease']}
    query_graph['nodes']['chemical'] = {'categories': ['biolink:ChemicalEntity']}
    pnode = 'disease'
    cnode = 'chemical'
    query_graph['edges']['t_edge'] = {'object': pnode, 'subject': cnode, 'predicates':['biolink:treats'], 'knowledge_type': 'inferred'}
    
    #https://github.com/RTXteam/RTX/blob/master/code/ARAX/Documentation/DSL_Documentation.md#inferactiondrug_treatment_graph_expansion
    infer_str = f"infer(action=drug_treatment_graph_expansion,node_curie={disease_id},qedge_id=t_edge,n_drugs {n_drugs})"
#    infer_str = "
    operations = {"actions": [infer_str, "return(message=true, store=true)"]}
    query = {
        'message':{'query_graph':query_graph},
        "operations": {"actions": [
            "create_message",
            "infer(action=chemical_gene_regulation_graph_expansion, subject_curie=CHEMBL.COMPOUND:CHEMBL1097205, regulation_type=increase, threshold=0.6, path_len=2, n_result_curies=1, n_paths=1)",
            "return(message=true, store=true)"
        ]}}
    
    query = {
        'message':{'query_graph':query_graph},
        "operations": {"actions": [
            "infer(action=drug_treatment_graph_expansion, node_curie=MONDO:0018874, qedge_id=t_edge, n_drugs=10)",
            "return(message=true, store=true)"
        ]}}
    m = {
            'message':{'query_graph':query_graph},
            'operations':operations
    }
#    return m
#XKCD
    return query

# %%
#Get data frame from result.
def score_parser(json_data):
    l = []
    query_node = json_data['message']['query_graph']['nodes']
    if 'on' in query_node:
        disease_idx = query_node['on']['ids'][0]
    elif 'n0' in query_node:
        disease_idx = query_node['n0']['ids'][0]
    elif 'disease' in query_node:
        disease_idx = query_node['disease']['ids'][0]
    else:
        print(query_node)
        raise Exception("Could not get Disease")
            
   # if disease_idx not in output_data:
   #     output_data[disease_idx] = dict()
    for result in json_data['message']['results']:
        node_bindings = result['node_bindings']
        if 'sn' in node_bindings:
            drug_idx = node_bindings['sn'][0]['id']
        elif 'n1' in node_bindings:
            drug_idx = node_bindings['n1'][0]['id']
        elif 'drug' in node_bindings:
            drug_idx = node_bindings['drug'][0]['id']
        elif "chemical" in node_bindings:
            drug_idx = node_bindings['chemical'][0]['id']
        else:
            print(node_bindings)
            raise Exception("Could not get Drug")
            
        #Noticed some Aragorn queries did not have scores in the results
        if 'score' not in result:
            return "error"
        score = result['score']
        if 'normalized_score' in result:
            normalized_score = result['normalized_score']
        else:
            normalized_score = 0
        l.append((disease_idx,drug_idx,score,normalized_score))
    df = pd.DataFrame(l, columns =['Disease', "Drug", 'Score', 'Normalized_Score'])
    return df

# %%
query_function_dict = {
    "robokop":create_query_for_aragorn,
    "aragorn":create_query_for_aragorn,
    "spoke":create_query_for_spoke,
    "bte":create_query,
    "medikanren":create_query,
    "arax":None
}

dis_idxs = []
drug_idxs = []
with open("../ARAX/disease_info.txt") as f:
    next(f)
    for line in f: dis_idxs.append(line.strip().split('\t')[0])
with open("../ARAX/drug_info.txt") as f:
    next(f)
    for line in f: drug_idxs.append(line.strip().split('\t')[0])
        
def getARAXResult(disease_name):
    disease_idx = dis_idxs.index(disease_name)
    with h5py.File('../ARAX/arax_10k_ranking_data.hdf5', 'r') as f:
        data = f[str(disease_idx)][()]
    l = []
    for (drug,score) in data: l.append([disease_name,drug_idxs[int(drug)],score,0.0])
    return pd.DataFrame(l, columns =['Disease', "Drug", 'Score', 'Normalized_Score'])

def checkIfAlreadyQueried(ara,disease_idx):
    fpath = os.path.join("ara_tables",ara, disease_idx + ".csv")
    queried = os.path.isfile(fpath) 
    df = None
    if(queried):
        df = pd.read_csv(fpath)
    return (queried,df)

#https://stackoverflow.com/questions/65834655/python-how-to-efficiently-write-read-a-json-file-inside-a-compressed-archive-i
def writeJsonToFile(ara,disease_idx,resp):
    fpath = os.path.join("ara_jsons",ara, disease_idx + ".zip")
#    with open(os.path.join("ara_jsons",ara, disease_idx + ".json.zip"),'w') as outf:
#        json.dump(resp.json(),outf, default=str, indent=2)
    dumped_json =  json.dumps(resp.json(), ensure_ascii=False, indent=2)
    with zipfile.ZipFile(fpath, mode="w", compression=zipfile.ZIP_DEFLATED, compresslevel=9) as zip_file:
        zip_file.writestr(disease_idx + '.json',data=dumped_json)
        
def writeDFToFile(ara,disease_idx,df):
    outf = os.path.join("ara_tables",ara, disease_idx + ".csv")
    #json.dump(resp.json(),outf, default=str, indent=2)
    df.to_csv(outf,index=False)

def runQuery(ara,disease_idx,query):
    logging.info(f"Beginning run for {disease_idx},{ara}")
    
    ara_resp = post_query(ara_urls[ara] + "/query",query)
    logging.info(f"Completed run for {disease_idx},{ara},{ara_resp.status_code}")
    if(ara_resp.status_code==502):
        raise ValueError("The query for the ara got a 502",ara,disease_idx)
    writeJsonToFile(ara,disease_idx,ara_resp)    
    print(ara,ara_resp)
    if("No ML predictions available for disease equivalent to" in ara_resp.text):
        ara_df = pd.DataFrame([], columns =['Disease', "Drug", 'Score', 'Normalized_Score'])
#        return pd.DataFrame([], columns =['Disease', "Drug", 'Score', 'Normalized_Score'])
    else:
        ara_df = getDfFromResponse(ara_resp,ara,disease_idx)
    writeDFToFile(ara,disease_idx,ara_df)
    print(ara_df.Disease.size)
    logging.info(f"Number results for {disease_idx},{ara},{ara_df.Disease.size}")
    return ara_df
    
def queryARA(ara,disease_idx,cache=True):
    if(ara=='arax'): return getARAXResult(disease_idx)
    if(cache):
        already_queried,ara_df = checkIfAlreadyQueried(ara,disease_idx)
        if(already_queried):
            return ara_df
    query = query_function_dict[ara](None,disease_idx)
    ara_df = runQuery(ara,disease_idx,query)
    return ara_df

# %%
def queryARA(ara,disease_idx,cache=True):
    if(ara=='arax'): return getARAXResult(disease_idx)
    if(cache):
        already_queried,ara_df = checkIfAlreadyQueried(ara,disease_idx)
        if(already_queried):
            return ara_df
    query = query_function_dict[ara](None,disease_idx)
    ara_df = runQuery(ara,disease_idx,query)
    return ara_df

# %%
#mondo = "MONDO:0019082"
#query = create_query(None,mondo)
#rk_df = runQuery("robokop",mondo,query)
#rk_df

# %%
#queryARA('arax',"MONDO:0005148").sort_values("Score")

# %%
#most_perscribed

# %%
aras = ["robokop","aragorn","spoke","bte","medikanren","arax"]
aras = ["robokop","spoke","bte","medikanren","arax"]

def testARAsForPair(mondo,target_drug):
    frames = {}
    for ara in aras:
        frames[ara] = queryARA(ara,mondo).sort_values("Score")
    drug_list = []
    for f in frames.values(): drug_list.extend(list(f.Drug))
    no_drug_dict = normalize_nodes.normalize_big_list(drug_list)
    ara_target_rank = {}
    for ara in aras:
        ara_drug_list = list(frames[ara].Drug)
        hit_idx = -1
        for i,drug in enumerate(ara_drug_list):
            if(no_drug_dict.get(drug,None)==target_drug):
                hit_idx = i
                break
        ara_target_rank[ara] = (hit_idx,len(ara_drug_list))
    return ara_target_rank
            
    #MONDO:0003019

# %%
#mondo = "MONDO:0021187"
#query = query_function_dict['robokop'](None,mondo)
#print(query)

# %%
'''
mondo = "MONDO:0003019"
frames = {}
for ara in aras:
    frames[ara] = queryARA(ara,mondo).sort_values("Score")
drug_list = []
for f in frames.values(): drug_list.extend(list(f.Drug))
no_drug_dict = normalize_nodes.normalize_big_list(drug_list)
ara_target_rank = {}
for ara in aras:
    ara_drug_list = list(frames[ara].Drug)
    hit_idx = -1
    for i,drug in enumerate(ara_drug_list):
        if(no_drug_dict.get(drug,None)==target_drug):
            hit_idx = i
            break
    ara_target_rank[ara] = (hit_idx,len(ara_drug_list))
    '''
# Out:
# Query is posted
# Query is posted
# Query is posted
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/miniconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/miniconda3/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[97], line 4
#       2 frames = {}
#       3 for ara in aras:
# ----> 4     frames[ara] = queryARA(ara,mondo).sort_values("Score")
#       5 drug_list = []
#       6 for f in frames.values(): drug_list.extend(list(f.Drug))
#
# Cell In[87], line 33, in queryARA(ara, disease_idx)
#      31 if("No ML predictions available for disease equivalent to" in ara_resp.text):
#      32     return pd.DataFrame([], columns =['Disease', "Drug", 'Score', 'Normalized_Score'])
# ---> 33 ara_df = getDfFromResponse(ara_resp)
#      34 return ara_df
#
# Cell In[42], line 9, in getDfFromResponse(resp)
#       7 def getDfFromResponse(resp):
#       8     if type(resp)==requests.models.Response:
# ----> 9         resp_json = resp.json()
#      10     elif type(resp)==dict:
#      11         resp_json = resp
#
# File ~/miniconda3/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def queryARAIgnoreErrors(ara,disease_idx,cache=True):
    try:
        queryARA(ara,disease_idx,cache)
    except Exception as e:
        print(e)
    return

def queryAllARAsInParallel(aras,disease_idx):
    pool = mp.Pool()
    for ara in aras:
        pool.apply_async(queryARAIgnoreErrors, args=(ara,disease_idx,False,))
    pool.close()
    pool.join()

#queryAllARAsInParallel(['bte','spoke','medikanren'],"MONDO:0035838")
        
#for disease in most_perscribed.ConditionID.unique():
#    print(disease)
#    queryARAIgnoreErrors('bte',disease)
#    queryARAIgnoreErrors('spoke',disease)
#    queryARAIgnoreErrors('medikanren',disease)
#    queryARAIgnoreErrors('robokop',disease)
# Out:
# Query is posted
# spoke <Response [200]>
# 'query_graph'
# Query is posted
# medikanren <Response [200]>
# 0
# Query is posted
# bte <Response [200]>
# 0

# %%
def buildDFForARA(ara):
    ara_dir = os.path.join("ara_tables",ara)
    dfs = [pd.DataFrame([], columns =['Disease', "Drug", 'Score', 'Normalized_Score'])]
    for fname in os.listdir(ara_dir):
        if(fname.endswith(".csv")):
            df = pd.read_csv(os.path.join(ara_dir,fname))
            dfs.append(df)
    return pd.concat(dfs)
#    return (queried,df)



def buildBigDF():
    big_dfs = []
    aras = ["robokop","spoke","bte","medikanren"]
    for ara in aras:
        ara_df = buildDFForARA(ara)
        ara_df['ara'] = ara
        big_dfs.append(ara_df)
    return pd.concat(big_dfs)

# %%
#drug_list_big_df = big_df.sort_values("Score",ascending=False).groupby(["Disease","ara"]).Drug.agg(list).to_frame().reset_index()

# %%
#drug_list = list(most_perscribed.DrugID.unique()) + list(big_df.Drug.unique())
#no_drug_dict = normalize_nodes.normalize_big_list(drug_list)

# %%
def testARA(disease,target_drug,ara):
    drug_list = list(big_df[(big_df.Disease==disease) & (big_df.ara==ara)].Drug)
    tot_hits = len(drug_list)
    hit_idx = -1
    for i,drug in enumerate(drug_list):
        if(no_drug_dict[drug]==no_drug_dict[target_drug]):
            hit_idx=i
            break
    return hit_idx,tot_hits

# %%
def getDataFromMostPerscribed():
    most_perscribed = pd.read_csv("https://raw.githubusercontent.com/TranslatorSRI/Benchmarks/main/config/MostPrescribed_2019/data.tsv",sep='\t') 
    l = []
    for ara in aras:
        for i,row in most_perscribed.iterrows():
            (hit_idx,tot_hits) = testARA(row.ConditionID,row.DrugID,ara)
            l.append([row.ConditionID,row.DrugID,hit_idx,tot_hits,ara])
    #        break
    df = pd.DataFrame(l,columns =["Disease","Drug","Hit_Idx","Num_Results","ara"])
    return df

# %%
#start_mondo = "MONDO:0001159"
#with open("../RANKING/mondo_list.csv") as f:
#    next(f)
#    start = False
#    for i,line in enumerate(f):
#        mondo_idx = line.strip().split(',')[0]
#        if(!start):
#            if(mondo_idx==start_mondo):
#                start=True
#            else:
#                continue
#        queryAllARAsInParallel(['bte','spoke','medikanren'],mondo_idx)
#        queryAllARAsInParallel(['spoke'],mondo_idx)
#        time.sleep(3)
#        if((i%100)==99):
#            time.sleep(60)
#        break

# %%
if(__name__=="__main__"):
    start_mondo = "MONDO:0001159"
    with open("../RANKING/mondo_list.csv") as f:
        next(f)
        wait = True
        for i,line in enumerate(f):
            mondo_idx = line.strip().split(',')[0]
            if(wait):
                if(mondo_idx==start_mondo):
                    wait=False
                else:
                    continue
            #print(wait,i,mondo_idx)
            queryAllARAsInParallel(['bte','spoke','medikanren'],mondo_idx)
# Out:
# False 727 MONDO:0001159
# False 728 MONDO:0001160
# False 729 MONDO:0001161
# False 730 MONDO:0001162
# False 731 MONDO:0001163
# False 732 MONDO:0001164
# False 733 MONDO:0001165
# False 734 MONDO:0001166
# False 735 MONDO:0001167
# False 736 MONDO:0001168
# False 737 MONDO:0001169
# False 738 MONDO:0001170
# False 739 MONDO:0001171
# False 740 MONDO:0001172
# False 741 MONDO:0001173
# False 742 MONDO:0001174
# False 743 MONDO:0001175
# False 744 MONDO:0001176
# False 745 MONDO:0001177
# False 746 MONDO:0001178
# False 747 MONDO:0001179
# False 748 MONDO:0001180
# False 749 MONDO:0001181
# False 750 MONDO:0001182
# False 751 MONDO:0001183
# False 752 MONDO:0001184
# False 753 MONDO:0001185
# False 754 MONDO:0001186
# False 755 MONDO:0001187
# False 756 MONDO:0001188
# False 757 MONDO:0001190
# False 758 MONDO:0001191
# False 759 MONDO:0001192
# False 760 MONDO:0001195
# False 761 MONDO:0001196
# False 762 MONDO:0001197
# False 763 MONDO:0001198
# False 764 MONDO:0001199
# False 765 MONDO:0001200
# False 766 MONDO:0001202
# False 767 MONDO:0001203
# False 768 MONDO:0001204
# False 769 MONDO:0001205
# False 770 MONDO:0001206
# False 771 MONDO:0001207
# False 772 MONDO:0001208
# False 773 MONDO:0001209
# False 774 MONDO:0001210
# False 775 MONDO:0001211
# False 776 MONDO:0001212
# False 777 MONDO:0001213
# False 778 MONDO:0001214
# False 779 MONDO:0001215
# False 780 MONDO:0001216
# False 781 MONDO:0001217
# False 782 MONDO:0001218
# False 783 MONDO:0001219
# False 784 MONDO:0001220
# False 785 MONDO:0001221
# False 786 MONDO:0001222
# False 787 MONDO:0001223
# False 788 MONDO:0001224
# False 789 MONDO:0001225
# False 790 MONDO:0001226
# False 791 MONDO:0001227
# False 792 MONDO:0001228
# False 793 MONDO:0001229
# False 794 MONDO:0001230
# False 795 MONDO:0001231
# False 796 MONDO:0001232
# False 797 MONDO:0001233
# False 798 MONDO:0001234
# False 799 MONDO:0001235
# False 800 MONDO:0001236
# False 801 MONDO:0001237
# False 802 MONDO:0001238
# False 803 MONDO:0001239
# False 804 MONDO:0001240
# False 805 MONDO:0001241
# False 806 MONDO:0001242
# False 807 MONDO:0001243
# False 808 MONDO:0001244
# False 809 MONDO:0001245
# False 810 MONDO:0001246
# False 811 MONDO:0001247
# False 812 MONDO:0001249
# False 813 MONDO:0001250
# False 814 MONDO:0001251
# False 815 MONDO:0001252
# False 816 MONDO:0001255
# False 817 MONDO:0001256
# False 818 MONDO:0001257
# False 819 MONDO:0001258
# False 820 MONDO:0001259
# False 821 MONDO:0001260
# False 822 MONDO:0001261
# False 823 MONDO:0001262
# False 824 MONDO:0001263
# False 825 MONDO:0001265
# False 826 MONDO:0003874
# False 827 MONDO:0003875
# False 828 MONDO:0003876
# False 829 MONDO:0003878
# False 830 MONDO:0003879
# False 831 MONDO:0003880
# False 832 MONDO:0003881
# False 833 MONDO:0003882
# False 834 MONDO:0003884
# False 835 MONDO:0003886
# False 836 MONDO:0003887
# False 837 MONDO:0003888
# False 838 MONDO:0003889
# False 839 MONDO:0003890
# False 840 MONDO:0003891
# False 841 MONDO:0003892
# False 842 MONDO:0003893
# False 843 MONDO:0003894
# False 844 MONDO:0003895
# False 845 MONDO:0003896
# False 846 MONDO:0003897
# False 847 MONDO:0003898
# False 848 MONDO:0003899
# False 849 MONDO:0003901
# False 850 MONDO:0003902
# False 851 MONDO:0003903
# False 852 MONDO:0003904
# False 853 MONDO:0003905
# False 854 MONDO:0003906
# False 855 MONDO:0003907
# False 856 MONDO:0003908
# False 857 MONDO:0003909
# False 858 MONDO:0003910
# False 859 MONDO:0003911
# False 860 MONDO:0003912
# False 861 MONDO:0003913
# False 862 MONDO:0003915
# False 863 MONDO:0003917
# False 864 MONDO:0003918
# False 865 MONDO:0003921
# False 866 MONDO:0003922
# False 867 MONDO:0003923
# False 868 MONDO:0003925
# False 869 MONDO:0003926
# False 870 MONDO:0003927
# False 871 MONDO:0003928
# False 872 MONDO:0003929
# False 873 MONDO:0003930
# False 874 MONDO:0003931
# False 875 MONDO:0003932
# False 876 MONDO:0003933
# False 877 MONDO:0003934
# False 878 MONDO:0003935
# False 879 MONDO:0003936
# False 880 MONDO:0003938
# False 881 MONDO:0003940
# False 882 MONDO:0003941
# False 883 MONDO:0003942
# False 884 MONDO:0003943
# False 885 MONDO:0003944
# False 886 MONDO:0003945
# False 887 MONDO:0003946
# False 888 MONDO:0003947
# False 889 MONDO:0003948
# False 890 MONDO:0003950
# False 891 MONDO:0003951
# False 892 MONDO:0003952
# False 893 MONDO:0003953
# False 894 MONDO:0003954
# False 895 MONDO:0003955
# False 896 MONDO:0003956
# False 897 MONDO:0003957
# False 898 MONDO:0003958
# False 899 MONDO:0003959
# False 900 MONDO:0003960
# False 901 MONDO:0003962
# False 902 MONDO:0003963
# False 903 MONDO:0003964
# False 904 MONDO:0003965
# False 905 MONDO:0003966
# False 906 MONDO:0003967
# False 907 MONDO:0003968
# False 908 MONDO:0003969
# False 909 MONDO:0003970
# False 910 MONDO:0003971
# False 911 MONDO:0003972
# False 912 MONDO:0003973
# False 913 MONDO:0003975
# False 914 MONDO:0003976
# False 915 MONDO:0003978
# False 916 MONDO:0003979
# False 917 MONDO:0003980
# False 918 MONDO:0003982
# False 919 MONDO:0003983
# False 920 MONDO:0003984
# False 921 MONDO:0003985
# False 922 MONDO:0003987
# False 923 MONDO:0003988
# False 924 MONDO:0003989
# False 925 MONDO:0003990
# False 926 MONDO:0005516
# False 927 MONDO:0005517
# False 928 MONDO:0005528
# False 929 MONDO:0005539
# False 930 MONDO:0005550
# False 931 MONDO:0005552
# False 932 MONDO:0005554
# False 933 MONDO:0005557
# False 934 MONDO:0005559
# False 935 MONDO:0005560
# False 936 MONDO:0005561
# False 937 MONDO:0005570
# False 938 MONDO:0005571
# False 939 MONDO:0005578
# False 940 MONDO:0005593
# False 941 MONDO:0005616
# False 942 MONDO:0005618
# False 943 MONDO:0005623
# False 944 MONDO:0005627
# False 945 MONDO:0005638
# False 946 MONDO:0005642
# False 947 MONDO:0005643
# False 948 MONDO:0005650
# False 949 MONDO:0005656
# False 950 MONDO:0005657
# False 951 MONDO:0005664
# False 952 MONDO:0005677
# False 953 MONDO:0005683
# False 954 MONDO:0005694
# False 955 MONDO:0005701
# False 956 MONDO:0005714
# False 957 MONDO:0005721
# False 958 MONDO:0005738
# False 959 MONDO:0005739
# False 960 MONDO:0005745
# False 961 MONDO:0005763
# False 962 MONDO:0005766
# False 963 MONDO:0005784
# False 964 MONDO:0005800
# False 965 MONDO:0005805
# False 966 MONDO:0005814
# False 967 MONDO:0005833
# False 968 MONDO:0005836
# False 969 MONDO:0005842
# False 970 MONDO:0005843
# False 971 MONDO:0005856
# False 972 MONDO:0005864
# False 973 MONDO:0005872
# False 974 MONDO:0005881
# False 975 MONDO:0005885
# False 976 MONDO:0005896
# False 977 MONDO:0005904
# False 978 MONDO:0005941
# False 979 MONDO:0005943
# False 980 MONDO:0005961
# False 981 MONDO:0005964
# False 982 MONDO:0005975
# False 983 MONDO:0005982
# False 984 MONDO:0005990
# False 985 MONDO:0006002
# False 986 MONDO:0006003
# False 987 MONDO:0006009
# False 988 MONDO:0006011
# False 989 MONDO:0006019
# False 990 MONDO:0006022
# False 991 MONDO:0006025
# False 992 MONDO:0006026
# False 993 MONDO:0006031
# False 994 MONDO:0006032
# False 995 MONDO:0006039
# False 996 MONDO:0006040
# False 997 MONDO:0006052
# False 998 MONDO:0006054
# False 999 MONDO:0006082
# False 1000 MONDO:0006106
# False 1001 MONDO:0006116
# False 1002 MONDO:0006130
# False 1003 MONDO:0006170
# False 1004 MONDO:0006210
# False 1005 MONDO:0006266
# False 1006 MONDO:0006294
# False 1007 MONDO:0006295
# False 1008 MONDO:0006320
# False 1009 MONDO:0006325
# False 1010 MONDO:0006329
# False 1011 MONDO:0006496
# False 1012 MONDO:0006497
# False 1013 MONDO:0006500
# False 1014 MONDO:0006504
# False 1015 MONDO:0006506
# False 1016 MONDO:0006510
# False 1017 MONDO:0006547
# False 1018 MONDO:0006552
# False 1019 MONDO:0006566
# False 1020 MONDO:0006626
# False 1021 MONDO:0006649
# False 1022 MONDO:0006652
# False 1023 MONDO:0006668
# False 1024 MONDO:0006670
# False 1025 MONDO:0006672
# False 1026 MONDO:0001379
# False 1027 MONDO:0001380
# False 1028 MONDO:0001381
# False 1029 MONDO:0001382
# False 1030 MONDO:0001383
# False 1031 MONDO:0001384
# False 1032 MONDO:0001385
# False 1033 MONDO:0001386
# False 1034 MONDO:0001387
# False 1035 MONDO:0001388
# False 1036 MONDO:0001389
# False 1037 MONDO:0001390
# False 1038 MONDO:0001391
# False 1039 MONDO:0001392
# False 1040 MONDO:0001393
# False 1041 MONDO:0001394
# False 1042 MONDO:0001395
# False 1043 MONDO:0001396
# False 1044 MONDO:0001397
# False 1045 MONDO:0001398
# False 1046 MONDO:0001399
# False 1047 MONDO:0001400
# False 1048 MONDO:0001401
# False 1049 MONDO:0001402
# False 1050 MONDO:0001403
# False 1051 MONDO:0001404
# False 1052 MONDO:0001405
# False 1053 MONDO:0001406
# False 1054 MONDO:0001407
# False 1055 MONDO:0001408
# False 1056 MONDO:0001409
# False 1057 MONDO:0001410
# False 1058 MONDO:0001411
# False 1059 MONDO:0001412
# False 1060 MONDO:0001413
# False 1061 MONDO:0001414
# False 1062 MONDO:0001415
# False 1063 MONDO:0001416
# False 1064 MONDO:0001417
# False 1065 MONDO:0001418
# False 1066 MONDO:0001419
# False 1067 MONDO:0001420
# False 1068 MONDO:0001421
# False 1069 MONDO:0001422
# False 1070 MONDO:0001423
# False 1071 MONDO:0001426
# False 1072 MONDO:0001427
# False 1073 MONDO:0001428
# False 1074 MONDO:0001429
# False 1075 MONDO:0001430
# False 1076 MONDO:0001431
# False 1077 MONDO:0001433
# False 1078 MONDO:0001434
# False 1079 MONDO:0001435
# False 1080 MONDO:0001436
# False 1081 MONDO:0001437
# False 1082 MONDO:0001438
# False 1083 MONDO:0001439
# False 1084 MONDO:0001440
# False 1085 MONDO:0001441
# False 1086 MONDO:0001442
# False 1087 MONDO:0001443
# False 1088 MONDO:0001444
# False 1089 MONDO:0001446
# False 1090 MONDO:0001447
# False 1091 MONDO:0001449
# False 1092 MONDO:0001451
# False 1093 MONDO:0001452
# False 1094 MONDO:0001453
# False 1095 MONDO:0001454
# False 1096 MONDO:0001455
# False 1097 MONDO:0001456
# False 1098 MONDO:0001457
# False 1099 MONDO:0001458
# False 1100 MONDO:0001459
# False 1101 MONDO:0001460
# False 1102 MONDO:0001461
# False 1103 MONDO:0001462
# False 1104 MONDO:0001463
# False 1105 MONDO:0001464
# False 1106 MONDO:0001465
# False 1107 MONDO:0001466
# False 1108 MONDO:0001468
# False 1109 MONDO:0001469
# False 1110 MONDO:0001470
# False 1111 MONDO:0001471
# False 1112 MONDO:0001472
# False 1113 MONDO:0001473
# False 1114 MONDO:0001474
# False 1115 MONDO:0001475
# False 1116 MONDO:0001476
# False 1117 MONDO:0001478
# False 1118 MONDO:0001479
# False 1119 MONDO:0001480
# False 1120 MONDO:0001481
# False 1121 MONDO:0001482
# False 1122 MONDO:0001484
# False 1123 MONDO:0001485
# False 1124 MONDO:0001487
# False 1125 MONDO:0001488
# False 1126 MONDO:0002120
# False 1127 MONDO:0002122
# False 1128 MONDO:0002123
# False 1129 MONDO:0002129
# False 1130 MONDO:0002134
# False 1131 MONDO:0002145
# False 1132 MONDO:0002149
# False 1133 MONDO:0002156
# False 1134 MONDO:0002164
# False 1135 MONDO:0002172
# False 1136 MONDO:0002175
# False 1137 MONDO:0002183
# False 1138 MONDO:0002187
# False 1139 MONDO:0002211
# False 1140 MONDO:0002234
# False 1141 MONDO:0002243
# False 1142 MONDO:0002245
# False 1143 MONDO:0002251
# False 1144 MONDO:0002254
# False 1145 MONDO:0002256
# False 1146 MONDO:0002259
# False 1147 MONDO:0002261
# False 1148 MONDO:0002263
# False 1149 MONDO:0002269
# False 1150 MONDO:0002271
# False 1151 MONDO:0002277
# False 1152 MONDO:0002278
# False 1153 MONDO:0002279
# False 1154 MONDO:0002280
# False 1155 MONDO:0002285
# False 1156 MONDO:0002305
# False 1157 MONDO:0002311
# False 1158 MONDO:0002312
# False 1159 MONDO:0002319
# False 1160 MONDO:0002320
# False 1161 MONDO:0002322
# False 1162 MONDO:0002326
# False 1163 MONDO:0002329
# False 1164 MONDO:0002332
# False 1165 MONDO:0002345
# False 1166 MONDO:0002352
# False 1167 MONDO:0002354
# False 1168 MONDO:0002356
# False 1169 MONDO:0002360
# False 1170 MONDO:0002366
# False 1171 MONDO:0002405
# False 1172 MONDO:0002406
# False 1173 MONDO:0002409
# False 1174 MONDO:0002415
# False 1175 MONDO:0002420
# False 1176 MONDO:0002427
# False 1177 MONDO:0002428
# False 1178 MONDO:0002447
# False 1179 MONDO:0002453
# False 1180 MONDO:0002460
# False 1181 MONDO:0002471
# False 1182 MONDO:0002479
# False 1183 MONDO:0002481
# False 1184 MONDO:0002491
# False 1185 MONDO:0002492
# False 1186 MONDO:0002513
# False 1187 MONDO:0002516
# False 1188 MONDO:0002519
# False 1189 MONDO:0002525
# False 1190 MONDO:0002529
# False 1191 MONDO:0002544
# False 1192 MONDO:0002546
# False 1193 MONDO:0002586
# False 1194 MONDO:0002602
# False 1195 MONDO:0002610
# False 1196 MONDO:0002612
# False 1197 MONDO:0002614
# False 1198 MONDO:0002633
# False 1199 MONDO:0002638
# False 1200 MONDO:0002639
# False 1201 MONDO:0002647
# False 1202 MONDO:0002650
# False 1203 MONDO:0002654
# False 1204 MONDO:0002656
# False 1205 MONDO:0002657
# False 1206 MONDO:0002696
# False 1207 MONDO:0002708
# False 1208 MONDO:0002714
# False 1209 MONDO:0002715
# False 1210 MONDO:0002721
# False 1211 MONDO:0002728
# False 1212 MONDO:0002731
# False 1213 MONDO:0002732
# False 1214 MONDO:0002738
# False 1215 MONDO:0002749
# False 1216 MONDO:0002771
# False 1217 MONDO:0002782
# False 1218 MONDO:0002800
# False 1219 MONDO:0002806
# False 1220 MONDO:0002807
# False 1221 MONDO:0002815
# False 1222 MONDO:0002816
# False 1223 MONDO:0002824
# False 1224 MONDO:0002869
# False 1225 MONDO:0002875
# False 1226 MONDO:0001601
# False 1227 MONDO:0001602
# False 1228 MONDO:0001603
# False 1229 MONDO:0001604
# False 1230 MONDO:0001606
# False 1231 MONDO:0001607
# False 1232 MONDO:0001608
# False 1233 MONDO:0001609
# False 1234 MONDO:0001610
# False 1235 MONDO:0001611
# False 1236 MONDO:0001612
# False 1237 MONDO:0001613
# False 1238 MONDO:0001614
# False 1239 MONDO:0001615
# False 1240 MONDO:0001616
# False 1241 MONDO:0001617
# False 1242 MONDO:0001618
# False 1243 MONDO:0001620
# False 1244 MONDO:0001621
# False 1245 MONDO:0001622
# False 1246 MONDO:0001623
# False 1247 MONDO:0001624
# False 1248 MONDO:0001625
# False 1249 MONDO:0001626
# False 1250 MONDO:0001627
# False 1251 MONDO:0001628
# False 1252 MONDO:0001629
# False 1253 MONDO:0001630
# False 1254 MONDO:0001631
# False 1255 MONDO:0001632
# False 1256 MONDO:0001633
# False 1257 MONDO:0001634
# False 1258 MONDO:0001635
# False 1259 MONDO:0001636
# False 1260 MONDO:0001637
# False 1261 MONDO:0001638
# False 1262 MONDO:0001639
# False 1263 MONDO:0001640
# False 1264 MONDO:0001641
# False 1265 MONDO:0001642
# False 1266 MONDO:0001643
# False 1267 MONDO:0001644
# False 1268 MONDO:0001645
# False 1269 MONDO:0001646
# False 1270 MONDO:0001647
# False 1271 MONDO:0001648
# False 1272 MONDO:0001649
# False 1273 MONDO:0001650
# False 1274 MONDO:0001651
# False 1275 MONDO:0001652
# False 1276 MONDO:0001653
# False 1277 MONDO:0001654
# False 1278 MONDO:0001655
# False 1279 MONDO:0001656
# False 1280 MONDO:0001657
# False 1281 MONDO:0001658
# False 1282 MONDO:0001660
# False 1283 MONDO:0001661
# False 1284 MONDO:0001663
# False 1285 MONDO:0001664
# False 1286 MONDO:0001673
# False 1287 MONDO:0001701
# False 1288 MONDO:0001703
# False 1289 MONDO:0001711
# False 1290 MONDO:0001750
# False 1291 MONDO:0001824
# False 1292 MONDO:0001825
# False 1293 MONDO:0001829
# False 1294 MONDO:0001835
# False 1295 MONDO:0001849
# False 1296 MONDO:0001854
# False 1297 MONDO:0001889
# False 1298 MONDO:0001898
# False 1299 MONDO:0001941
# False 1300 MONDO:0001952
# False 1301 MONDO:0002008
# False 1302 MONDO:0002013
# False 1303 MONDO:0002021
# False 1304 MONDO:0002022
# False 1305 MONDO:0002025
# False 1306 MONDO:0002026
# False 1307 MONDO:0002028
# False 1308 MONDO:0002033
# False 1309 MONDO:0002034
# False 1310 MONDO:0002037
# False 1311 MONDO:0002039
# False 1312 MONDO:0002040
# False 1313 MONDO:0002041
# False 1314 MONDO:0002043
# False 1315 MONDO:0002049
# False 1316 MONDO:0002050
# False 1317 MONDO:0002051
# False 1318 MONDO:0002052
# False 1319 MONDO:0002081
# False 1320 MONDO:0002082
# False 1321 MONDO:0002087
# False 1322 MONDO:0002099
# False 1323 MONDO:0002100
# False 1324 MONDO:0002102
# False 1325 MONDO:0002103
# False 1326 MONDO:0016106
# False 1327 MONDO:0016112
# False 1328 MONDO:0016113
# False 1329 MONDO:0016122
# False 1330 MONDO:0016156
# False 1331 MONDO:0016184
# False 1332 MONDO:0016185
# False 1333 MONDO:0016342
# False 1334 MONDO:0016387
# False 1335 MONDO:0016642
# False 1336 MONDO:0016695
# False 1337 MONDO:0016755
# False 1338 MONDO:0016764
# False 1339 MONDO:0016830
# False 1340 MONDO:0017127
# False 1341 MONDO:0017210
# False 1342 MONDO:0017236
# False 1343 MONDO:0017270
# False 1344 MONDO:0017276
# False 1345 MONDO:0017279
# False 1346 MONDO:0017373
# False 1347 MONDO:0017393
# False 1348 MONDO:0017578
# False 1349 MONDO:0017651
# False 1350 MONDO:0017704
# False 1351 MONDO:0017745
# False 1352 MONDO:0017768
# False 1353 MONDO:0017795
# False 1354 MONDO:0017814
# False 1355 MONDO:0017853
# False 1356 MONDO:0017881
# False 1357 MONDO:0018076
# False 1358 MONDO:0018077
# False 1359 MONDO:0018078
# False 1360 MONDO:0018102
# False 1361 MONDO:0018177
# False 1362 MONDO:0018234
# False 1363 MONDO:0018276
# False 1364 MONDO:0018312
# False 1365 MONDO:0018320
# False 1366 MONDO:0018329
# False 1367 MONDO:0018364
# False 1368 MONDO:0018373
# False 1369 MONDO:0018454
# False 1370 MONDO:0018491
# False 1371 MONDO:0018562
# False 1372 MONDO:0018612
# False 1373 MONDO:0018661
# False 1374 MONDO:0018855
# False 1375 MONDO:0018869
# False 1376 MONDO:0018882
# False 1377 MONDO:0018898
# False 1378 MONDO:0018905
# False 1379 MONDO:0018908
# False 1380 MONDO:0018916
# False 1381 MONDO:0018925
# False 1382 MONDO:0018935
# False 1383 MONDO:0018940
# False 1384 MONDO:0019040
# False 1385 MONDO:0019050
# False 1386 MONDO:0019052
# False 1387 MONDO:0019056
# False 1388 MONDO:0019060
# False 1389 MONDO:0019095
# False 1390 MONDO:0019136
# False 1391 MONDO:0019147
# False 1392 MONDO:0019189
# False 1393 MONDO:0019200
# False 1394 MONDO:0019222
# False 1395 MONDO:0019224
# False 1396 MONDO:0019226
# False 1397 MONDO:0019239
# False 1398 MONDO:0019243
# False 1399 MONDO:0019245
# False 1400 MONDO:0019249
# False 1401 MONDO:0019280
# False 1402 MONDO:0019288
# False 1403 MONDO:0019289
# False 1404 MONDO:0019350
# False 1405 MONDO:0019376
# False 1406 MONDO:0019464
# False 1407 MONDO:0019496
# False 1408 MONDO:0019524
# False 1409 MONDO:0019530
# False 1410 MONDO:0019588
# False 1411 MONDO:0019633
# False 1412 MONDO:0019695
# False 1413 MONDO:0019722
# False 1414 MONDO:0019737
# False 1415 MONDO:0019743
# False 1416 MONDO:0019796
# False 1417 MONDO:0019950
# False 1418 MONDO:0019956
# False 1419 MONDO:0020010
# False 1420 MONDO:0020067
# False 1421 MONDO:0020099
# False 1422 MONDO:0020120
# False 1423 MONDO:0020123
# False 1424 MONDO:0020127
# False 1425 MONDO:0020128
# False 1426 MONDO:0021459
# False 1427 MONDO:0021474
# False 1428 MONDO:0021503
# False 1429 MONDO:0021529
# False 1430 MONDO:0021533
# False 1431 MONDO:0021562
# False 1432 MONDO:0021568
# False 1433 MONDO:0021635
# False 1434 MONDO:0021641
# False 1435 MONDO:0021651
# False 1436 MONDO:0021658
# False 1437 MONDO:0021666
# False 1438 MONDO:0021669
# False 1439 MONDO:0021670
# False 1440 MONDO:0021674
# False 1441 MONDO:0021680
# False 1442 MONDO:0021699
# False 1443 MONDO:0021723
# False 1444 MONDO:0021747
# False 1445 MONDO:0022202
# False 1446 MONDO:0023369
# False 1447 MONDO:0023603
# False 1448 MONDO:0023865
# False 1449 MONDO:0024237
# False 1450 MONDO:0024257
# False 1451 MONDO:0024268
# False 1452 MONDO:0024270
# False 1453 MONDO:0024271
# False 1454 MONDO:0024276
# False 1455 MONDO:0024290
# False 1456 MONDO:0024294
# False 1457 MONDO:0024295
# False 1458 MONDO:0024298
# False 1459 MONDO:0024300
# False 1460 MONDO:0024311
# False 1461 MONDO:0024318
# False 1462 MONDO:0024334
# False 1463 MONDO:0024338
# False 1464 MONDO:0024339
# False 1465 MONDO:0024352
# False 1466 MONDO:0024355
# False 1467 MONDO:0024416
# False 1468 MONDO:0024417
# False 1469 MONDO:0024422
# False 1470 MONDO:0024461
# False 1471 MONDO:0024476
# False 1472 MONDO:0024477
# False 1473 MONDO:0024479
# False 1474 MONDO:0024481
# False 1475 MONDO:0024487
# False 1476 MONDO:0024491
# False 1477 MONDO:0024495
# False 1478 MONDO:0024503
# False 1479 MONDO:0024575
# False 1480 MONDO:0024582
# False 1481 MONDO:0024610
# False 1482 MONDO:0024616
# False 1483 MONDO:0024619
# False 1484 MONDO:0024623
# False 1485 MONDO:0024625
# False 1486 MONDO:0024633
# False 1487 MONDO:0024634
# False 1488 MONDO:0024635
# False 1489 MONDO:0024645
# False 1490 MONDO:0024651
# False 1491 MONDO:0024654
# False 1492 MONDO:0024666
# False 1493 MONDO:0024757
# False 1494 MONDO:0025294
# False 1495 MONDO:0025511
# False 1496 MONDO:0027772
# False 1497 MONDO:0035682
# False 1498 MONDO:0036781
# False 1499 MONDO:0037003
# False 1500 MONDO:0037251
# False 1501 MONDO:0037792
# False 1502 MONDO:0037872
# False 1503 MONDO:0037938
# False 1504 MONDO:0040678
# False 1505 MONDO:0041154
# False 1506 MONDO:0041825
# False 1507 MONDO:0042488
# False 1508 MONDO:0042489
# False 1509 MONDO:0043218
# False 1510 MONDO:0043424
# False 1511 MONDO:0043479
# False 1512 MONDO:0043494
# False 1513 MONDO:0043541
# False 1514 MONDO:0043693
# False 1515 MONDO:0043786
# False 1516 MONDO:0044334
# False 1517 MONDO:0044335
# False 1518 MONDO:0044345
# False 1519 MONDO:0044348
# False 1520 MONDO:0044704
# False 1521 MONDO:0044925
# False 1522 MONDO:0044986
# False 1523 MONDO:0045003
# False 1524 MONDO:0045004
# False 1525 MONDO:0045013
# False 1526 MONDO:0004247
# False 1527 MONDO:0004251
# False 1528 MONDO:0004259
# False 1529 MONDO:0004277
# False 1530 MONDO:0004298
# False 1531 MONDO:0004335
# False 1532 MONDO:0004355
# False 1533 MONDO:0004379
# False 1534 MONDO:0004382
# False 1535 MONDO:0004390
# False 1536 MONDO:0004403
# False 1537 MONDO:0004425
# False 1538 MONDO:0004496
# False 1539 MONDO:0004497
# False 1540 MONDO:0004508
# False 1541 MONDO:0004577
# False 1542 MONDO:0004579
# False 1543 MONDO:0004580
# False 1544 MONDO:0004588
# False 1545 MONDO:0004592
# False 1546 MONDO:0004596
# False 1547 MONDO:0004627
# False 1548 MONDO:0004630
# False 1549 MONDO:0004631
# False 1550 MONDO:0004634
# False 1551 MONDO:0004647
# False 1552 MONDO:0004651
# False 1553 MONDO:0004660
# False 1554 MONDO:0004664
# False 1555 MONDO:0004669
# False 1556 MONDO:0004674
# False 1557 MONDO:0004678
# False 1558 MONDO:0004681
# False 1559 MONDO:0004689
# False 1560 MONDO:0004699
# False 1561 MONDO:0004701
# False 1562 MONDO:0004715
# False 1563 MONDO:0004730
# False 1564 MONDO:0004736
# False 1565 MONDO:0004750
# False 1566 MONDO:0004751
# False 1567 MONDO:0004756
# False 1568 MONDO:0004767
# False 1569 MONDO:0004768
# False 1570 MONDO:0004779
# False 1571 MONDO:0004781
# False 1572 MONDO:0004785
# False 1573 MONDO:0004795
# False 1574 MONDO:0004796
# False 1575 MONDO:0004797
# False 1576 MONDO:0004804
# False 1577 MONDO:0004805
# False 1578 MONDO:0004820
# False 1579 MONDO:0004821
# False 1580 MONDO:0004843
# False 1581 MONDO:0004847
# False 1582 MONDO:0004849
# False 1583 MONDO:0004857
# False 1584 MONDO:0004860
# False 1585 MONDO:0004866
# False 1586 MONDO:0004867
# False 1587 MONDO:0004869
# False 1588 MONDO:0004884
# False 1589 MONDO:0004892
# False 1590 MONDO:0004896
# False 1591 MONDO:0004903
# False 1592 MONDO:0004926
# False 1593 MONDO:0004928
# False 1594 MONDO:0004934
# False 1595 MONDO:0004944
# False 1596 MONDO:0004958
# False 1597 MONDO:0004963
# False 1598 MONDO:0004966
# False 1599 MONDO:0004967
# False 1600 MONDO:0004970
# False 1601 MONDO:0004971
# False 1602 MONDO:0004972
# False 1603 MONDO:0004979
# False 1604 MONDO:0004980
# False 1605 MONDO:0004985
# False 1606 MONDO:0004987
# False 1607 MONDO:0004988
# False 1608 MONDO:0004991
# False 1609 MONDO:0004992
# False 1610 MONDO:0004993
# False 1611 MONDO:0004994
# False 1612 MONDO:0004995
# False 1613 MONDO:0005009
# False 1614 MONDO:0005010
# False 1615 MONDO:0005011
# False 1616 MONDO:0005012
# False 1617 MONDO:0005015
# False 1618 MONDO:0005020
# False 1619 MONDO:0005025
# False 1620 MONDO:0005027
# False 1621 MONDO:0005035
# False 1622 MONDO:0005036
# False 1623 MONDO:0005039
# False 1624 MONDO:0005041
# False 1625 MONDO:0005044
# False 1626 MONDO:0003631
# False 1627 MONDO:0003632
# False 1628 MONDO:0003633
# False 1629 MONDO:0003634
# False 1630 MONDO:0003635
# False 1631 MONDO:0003636
# False 1632 MONDO:0003637
# False 1633 MONDO:0003638
# False 1634 MONDO:0003639
# False 1635 MONDO:0003640
# False 1636 MONDO:0003643
# False 1637 MONDO:0003644
# False 1638 MONDO:0003645
# False 1639 MONDO:0003646
# False 1640 MONDO:0003647
# False 1641 MONDO:0003650
# False 1642 MONDO:0003651
# False 1643 MONDO:0003652
# False 1644 MONDO:0003653
# False 1645 MONDO:0003654
# False 1646 MONDO:0003655
# False 1647 MONDO:0003656
# False 1648 MONDO:0003658
# False 1649 MONDO:0003661
# False 1650 MONDO:0003663
# False 1651 MONDO:0003665
# False 1652 MONDO:0003666
# False 1653 MONDO:0003668
# False 1654 MONDO:0003669
# False 1655 MONDO:0003670
# False 1656 MONDO:0003671
# False 1657 MONDO:0003672
# False 1658 MONDO:0003673
# False 1659 MONDO:0003675
# False 1660 MONDO:0003676
# False 1661 MONDO:0003677
# False 1662 MONDO:0003678
# False 1663 MONDO:0003679
# False 1664 MONDO:0003680
# False 1665 MONDO:0003681
# False 1666 MONDO:0003682
# False 1667 MONDO:0003684
# False 1668 MONDO:0003685
# False 1669 MONDO:0003686
# False 1670 MONDO:0003687
# False 1671 MONDO:0003688
# False 1672 MONDO:0003690
# False 1673 MONDO:0003691
# False 1674 MONDO:0003692
# False 1675 MONDO:0003693
# False 1676 MONDO:0003694
# False 1677 MONDO:0003695
# False 1678 MONDO:0003697
# False 1679 MONDO:0003698
# False 1680 MONDO:0003700
# False 1681 MONDO:0003701
# False 1682 MONDO:0003702
# False 1683 MONDO:0003704
# False 1684 MONDO:0003705
# False 1685 MONDO:0003706
# False 1686 MONDO:0003707
# False 1687 MONDO:0003708
# False 1688 MONDO:0003709
# False 1689 MONDO:0003710
# False 1690 MONDO:0003712
# False 1691 MONDO:0003713
# False 1692 MONDO:0003714
# False 1693 MONDO:0003715
# False 1694 MONDO:0003716
# False 1695 MONDO:0003717
# False 1696 MONDO:0003719
# False 1697 MONDO:0003720
# False 1698 MONDO:0003721
# False 1699 MONDO:0003722
# False 1700 MONDO:0003723
# False 1701 MONDO:0003724
# False 1702 MONDO:0003725
# False 1703 MONDO:0003726
# False 1704 MONDO:0003727
# False 1705 MONDO:0003728
# False 1706 MONDO:0003729
# False 1707 MONDO:0003730
# False 1708 MONDO:0003731
# False 1709 MONDO:0003732
# False 1710 MONDO:0003733
# False 1711 MONDO:0003734
# False 1712 MONDO:0003735
# False 1713 MONDO:0003736
# False 1714 MONDO:0003737
# False 1715 MONDO:0003738
# False 1716 MONDO:0003740
# False 1717 MONDO:0003741
# False 1718 MONDO:0003742
# False 1719 MONDO:0003743
# False 1720 MONDO:0003744
# False 1721 MONDO:0003745
# False 1722 MONDO:0003746
# False 1723 MONDO:0003747
# False 1724 MONDO:0003748
# False 1725 MONDO:0003750
# False 1726 MONDO:0001046
# False 1727 MONDO:0001048
# False 1728 MONDO:0001049
# False 1729 MONDO:0001050
# False 1730 MONDO:0001051
# False 1731 MONDO:0001052
# False 1732 MONDO:0001053
# False 1733 MONDO:0001054
# False 1734 MONDO:0001055
# False 1735 MONDO:0001056
# False 1736 MONDO:0001057
# False 1737 MONDO:0001059
# False 1738 MONDO:0001060
# False 1739 MONDO:0001061
# False 1740 MONDO:0001062
# False 1741 MONDO:0001063
# False 1742 MONDO:0001064
# False 1743 MONDO:0001065
# False 1744 MONDO:0001066
# False 1745 MONDO:0001067
# False 1746 MONDO:0001068
# False 1747 MONDO:0001071
# False 1748 MONDO:0001072
# False 1749 MONDO:0001073
# False 1750 MONDO:0001074
# False 1751 MONDO:0001075
# False 1752 MONDO:0001076
# False 1753 MONDO:0001078
# False 1754 MONDO:0001079
# False 1755 MONDO:0001080
# False 1756 MONDO:0001081
# False 1757 MONDO:0001082
# False 1758 MONDO:0001083
# False 1759 MONDO:0001084
# False 1760 MONDO:0001085
# False 1761 MONDO:0001086
# False 1762 MONDO:0001087
# False 1763 MONDO:0001088
# False 1764 MONDO:0001089
# False 1765 MONDO:0001090
# False 1766 MONDO:0001091
# False 1767 MONDO:0001092
# False 1768 MONDO:0001093
# False 1769 MONDO:0001094
# False 1770 MONDO:0001095
# False 1771 MONDO:0001096
# False 1772 MONDO:0001098
# False 1773 MONDO:0001099
# False 1774 MONDO:0001100
# False 1775 MONDO:0001101
# False 1776 MONDO:0001103
# False 1777 MONDO:0001104
# False 1778 MONDO:0001105
# False 1779 MONDO:0001106
# False 1780 MONDO:0001108
# False 1781 MONDO:0001109
# False 1782 MONDO:0001110
# False 1783 MONDO:0001112
# False 1784 MONDO:0001113
# False 1785 MONDO:0001114
# False 1786 MONDO:0001115
# False 1787 MONDO:0001116
# False 1788 MONDO:0001117
# False 1789 MONDO:0001118
# False 1790 MONDO:0001119
# False 1791 MONDO:0001120
# False 1792 MONDO:0001121
# False 1793 MONDO:0001122
# False 1794 MONDO:0001123
# False 1795 MONDO:0001125
# False 1796 MONDO:0001126
# False 1797 MONDO:0001127
# False 1798 MONDO:0001128
# False 1799 MONDO:0001129
# False 1800 MONDO:0001130
# False 1801 MONDO:0001132
# False 1802 MONDO:0001133
# False 1803 MONDO:0001134
# False 1804 MONDO:0001135
# False 1805 MONDO:0001136
# False 1806 MONDO:0001137
# False 1807 MONDO:0001138
# False 1808 MONDO:0001139
# False 1809 MONDO:0001141
# False 1810 MONDO:0001142
# False 1811 MONDO:0001143
# False 1812 MONDO:0001144
# False 1813 MONDO:0001145
# False 1814 MONDO:0001146
# False 1815 MONDO:0001147
# False 1816 MONDO:0001148
# False 1817 MONDO:0001149
# False 1818 MONDO:0001150
# False 1819 MONDO:0001151
# False 1820 MONDO:0001152
# False 1821 MONDO:0001153
# False 1822 MONDO:0001154
# False 1823 MONDO:0001155
# False 1824 MONDO:0001156
# False 1825 MONDO:0001157
# False 1826 MONDO:0006005
# False 1827 MONDO:0006006
# False 1828 MONDO:0006007
# False 1829 MONDO:0006008
# False 1830 MONDO:0006010
# False 1831 MONDO:0006012
# False 1832 MONDO:0006013
# False 1833 MONDO:0006014
# False 1834 MONDO:0006015
# False 1835 MONDO:0006018
# False 1836 MONDO:0006021
# False 1837 MONDO:0006027
# False 1838 MONDO:0006028
# False 1839 MONDO:0006029
# False 1840 MONDO:0006030
# False 1841 MONDO:0006033
# False 1842 MONDO:0006034
# False 1843 MONDO:0006035
# False 1844 MONDO:0006036
# False 1845 MONDO:0006037
# False 1846 MONDO:0006038
# False 1847 MONDO:0006041
# False 1848 MONDO:0006042
# False 1849 MONDO:0006043
# False 1850 MONDO:0006044
# False 1851 MONDO:0006045
# False 1852 MONDO:0006046
# False 1853 MONDO:0006047
# False 1854 MONDO:0006049
# False 1855 MONDO:0006050
# False 1856 MONDO:0006053
# False 1857 MONDO:0006055
# False 1858 MONDO:0006056
# False 1859 MONDO:0006058
# False 1860 MONDO:0006059
# False 1861 MONDO:0006060
# False 1862 MONDO:0006061
# False 1863 MONDO:0006065
# False 1864 MONDO:0006066
# False 1865 MONDO:0006067
# False 1866 MONDO:0006068
# False 1867 MONDO:0006069
# False 1868 MONDO:0006071
# False 1869 MONDO:0006073
# False 1870 MONDO:0006074
# False 1871 MONDO:0006075
# False 1872 MONDO:0006076
# False 1873 MONDO:0006077
# False 1874 MONDO:0006078
# False 1875 MONDO:0006079
# False 1876 MONDO:0006081
# False 1877 MONDO:0006085
# False 1878 MONDO:0006086
# False 1879 MONDO:0006087
# False 1880 MONDO:0006088
# False 1881 MONDO:0006090
# False 1882 MONDO:0006091
# False 1883 MONDO:0006092
# False 1884 MONDO:0006093
# False 1885 MONDO:0006094
# False 1886 MONDO:0006095
# False 1887 MONDO:0006096
# False 1888 MONDO:0006097
# False 1889 MONDO:0006098
# False 1890 MONDO:0006102
# False 1891 MONDO:0006103
# False 1892 MONDO:0006104
# False 1893 MONDO:0006105
# False 1894 MONDO:0006107
# False 1895 MONDO:0006108
# False 1896 MONDO:0006109
# False 1897 MONDO:0006111
# False 1898 MONDO:0006112
# False 1899 MONDO:0006115
# False 1900 MONDO:0006117
# False 1901 MONDO:0006118
# False 1902 MONDO:0006119
# False 1903 MONDO:0006120
# False 1904 MONDO:0006121
# False 1905 MONDO:0006122
# False 1906 MONDO:0006123
# False 1907 MONDO:0006126
# False 1908 MONDO:0006128
# False 1909 MONDO:0006131
# False 1910 MONDO:0006132
# False 1911 MONDO:0006133
# False 1912 MONDO:0006134
# False 1913 MONDO:0006135
# False 1914 MONDO:0006137
# False 1915 MONDO:0006138
# False 1916 MONDO:0006139
# False 1917 MONDO:0006140
# False 1918 MONDO:0006141
# False 1919 MONDO:0006142
# False 1920 MONDO:0006143
# False 1921 MONDO:0006144
# False 1922 MONDO:0006145
# False 1923 MONDO:0006146
# False 1924 MONDO:0006149
# False 1925 MONDO:0006150
# False 1926 MONDO:0002894
# False 1927 MONDO:0002898
# False 1928 MONDO:0002903
# False 1929 MONDO:0002905
# False 1930 MONDO:0002908
# False 1931 MONDO:0002909
# False 1932 MONDO:0002912
# False 1933 MONDO:0002917
# False 1934 MONDO:0002922
# False 1935 MONDO:0002933
# False 1936 MONDO:0002941
# False 1937 MONDO:0002977
# False 1938 MONDO:0002995
# False 1939 MONDO:0003004
# False 1940 MONDO:0003036
# False 1941 MONDO:0003037
# False 1942 MONDO:0003059
# False 1943 MONDO:0003085
# False 1944 MONDO:0003098
# False 1945 MONDO:0003105
# False 1946 MONDO:0003113
# False 1947 MONDO:0003117
# False 1948 MONDO:0003122
# False 1949 MONDO:0003125
# False 1950 MONDO:0003134
# False 1951 MONDO:0003150
# False 1952 MONDO:0003182
# False 1953 MONDO:0003184
# False 1954 MONDO:0003198
# False 1955 MONDO:0003218
# False 1956 MONDO:0003220
# False 1957 MONDO:0003225
# False 1958 MONDO:0003231
# False 1959 MONDO:0003240
# False 1960 MONDO:0003241
# False 1961 MONDO:0003252
# False 1962 MONDO:0003266
# False 1963 MONDO:0003274
# False 1964 MONDO:0003276
# False 1965 MONDO:0003282
# False 1966 MONDO:0003283
# False 1967 MONDO:0003299
# False 1968 MONDO:0003319
# False 1969 MONDO:0003327
# False 1970 MONDO:0003346
# False 1971 MONDO:0003366
# False 1972 MONDO:0003382
# False 1973 MONDO:0003394
# False 1974 MONDO:0003409
# False 1975 MONDO:0003425
# False 1976 MONDO:0003432
# False 1977 MONDO:0003438
# False 1978 MONDO:0003441
# False 1979 MONDO:0003538
# False 1980 MONDO:0003541
# False 1981 MONDO:0003543
# False 1982 MONDO:0003544
# False 1983 MONDO:0003546
# False 1984 MONDO:0003569
# False 1985 MONDO:0003579
# False 1986 MONDO:0003584
# False 1987 MONDO:0003607
# False 1988 MONDO:0003608
# False 1989 MONDO:0003617
# False 1990 MONDO:0003619
# False 1991 MONDO:0003620
# False 1992 MONDO:0003641
# False 1993 MONDO:0003648
# False 1994 MONDO:0003649
# False 1995 MONDO:0003659
# False 1996 MONDO:0003660
# False 1997 MONDO:0003664
# False 1998 MONDO:0003674
# False 1999 MONDO:0003689
# False 2000 MONDO:0003699
# False 2001 MONDO:0003718
# False 2002 MONDO:0003739
# False 2003 MONDO:0003749
# False 2004 MONDO:0003767
# False 2005 MONDO:0003778
# False 2006 MONDO:0003780
# False 2007 MONDO:0003785
# False 2008 MONDO:0003799
# False 2009 MONDO:0003832
# False 2010 MONDO:0003847
# False 2011 MONDO:0003885
# False 2012 MONDO:0003900
# False 2013 MONDO:0003916
# False 2014 MONDO:0003924
# False 2015 MONDO:0003937
# False 2016 MONDO:0003939
# False 2017 MONDO:0004010
# False 2018 MONDO:0004021
# False 2019 MONDO:0004069
# False 2020 MONDO:0004095
# False 2021 MONDO:0004180
# False 2022 MONDO:0004183
# False 2023 MONDO:0004184
# False 2024 MONDO:0004235
# False 2025 MONDO:0004245
# False 2026 MONDO:0002695
# False 2027 MONDO:0002697
# False 2028 MONDO:0002698
# False 2029 MONDO:0002701
# False 2030 MONDO:0002702
# False 2031 MONDO:0002703
# False 2032 MONDO:0002705
# False 2033 MONDO:0002706
# False 2034 MONDO:0002707
# False 2035 MONDO:0002710
# False 2036 MONDO:0002712
# False 2037 MONDO:0002713
# False 2038 MONDO:0002716
# False 2039 MONDO:0002717
# False 2040 MONDO:0002718
# False 2041 MONDO:0002719
# False 2042 MONDO:0002720
# False 2043 MONDO:0002722
# False 2044 MONDO:0002724
# False 2045 MONDO:0002726
# False 2046 MONDO:0002727
# False 2047 MONDO:0002729
# False 2048 MONDO:0002730
# False 2049 MONDO:0002734
# False 2050 MONDO:0002735
# False 2051 MONDO:0002736
# False 2052 MONDO:0002737
# False 2053 MONDO:0002739
# False 2054 MONDO:0002740
# False 2055 MONDO:0002741
# False 2056 MONDO:0002742
# False 2057 MONDO:0002744
# False 2058 MONDO:0002745
# False 2059 MONDO:0002746
# False 2060 MONDO:0002747
# False 2061 MONDO:0002748
# False 2062 MONDO:0002750
# False 2063 MONDO:0002751
# False 2064 MONDO:0002752
# False 2065 MONDO:0002754
# False 2066 MONDO:0002755
# False 2067 MONDO:0002756
# False 2068 MONDO:0002757
# False 2069 MONDO:0002758
# False 2070 MONDO:0002759
# False 2071 MONDO:0002760
# False 2072 MONDO:0002761
# False 2073 MONDO:0002762
# False 2074 MONDO:0002763
# False 2075 MONDO:0002764
# False 2076 MONDO:0002765
# False 2077 MONDO:0002766
# False 2078 MONDO:0002768
# False 2079 MONDO:0002769
# False 2080 MONDO:0002770
# False 2081 MONDO:0002772
# False 2082 MONDO:0002775
# False 2083 MONDO:0002776
# False 2084 MONDO:0002778
# False 2085 MONDO:0002779
# False 2086 MONDO:0002781
# False 2087 MONDO:0002783
# False 2088 MONDO:0002785
# False 2089 MONDO:0002786
# False 2090 MONDO:0002787
# False 2091 MONDO:0002788
# False 2092 MONDO:0002789
# False 2093 MONDO:0002790
# False 2094 MONDO:0002791
# False 2095 MONDO:0002792
# False 2096 MONDO:0002794
# False 2097 MONDO:0002795
# False 2098 MONDO:0002796
# False 2099 MONDO:0002797
# False 2100 MONDO:0002798
# False 2101 MONDO:0002799
# False 2102 MONDO:0002801
# False 2103 MONDO:0002802
# False 2104 MONDO:0002803
# False 2105 MONDO:0002804
# False 2106 MONDO:0002805
# False 2107 MONDO:0002808
# False 2108 MONDO:0002809
# False 2109 MONDO:0002810
# False 2110 MONDO:0002811
# False 2111 MONDO:0002812
# False 2112 MONDO:0002813
# False 2113 MONDO:0002814
# False 2114 MONDO:0002817
# False 2115 MONDO:0002821
# False 2116 MONDO:0002822
# False 2117 MONDO:0002828
# False 2118 MONDO:0002829
# False 2119 MONDO:0002831
# False 2120 MONDO:0002832
# False 2121 MONDO:0002833
# False 2122 MONDO:0002834
# False 2123 MONDO:0002836
# False 2124 MONDO:0002837
# False 2125 MONDO:0002839
# False 2126 MONDO:0004343
# False 2127 MONDO:0004344
# False 2128 MONDO:0004345
# False 2129 MONDO:0004346
# False 2130 MONDO:0004348
# False 2131 MONDO:0004349
# False 2132 MONDO:0004350
# False 2133 MONDO:0004351
# False 2134 MONDO:0004352
# False 2135 MONDO:0004353
# False 2136 MONDO:0004354
# False 2137 MONDO:0004356
# False 2138 MONDO:0004357
# False 2139 MONDO:0004358
# False 2140 MONDO:0004359
# False 2141 MONDO:0004360
# False 2142 MONDO:0004361
# False 2143 MONDO:0004363
# False 2144 MONDO:0004364
# False 2145 MONDO:0004365
# False 2146 MONDO:0004366
# False 2147 MONDO:0004367
# False 2148 MONDO:0004368
# False 2149 MONDO:0004369
# False 2150 MONDO:0004370
# False 2151 MONDO:0004371
# False 2152 MONDO:0004372
# False 2153 MONDO:0004373
# False 2154 MONDO:0004374
# False 2155 MONDO:0004375
# False 2156 MONDO:0004376
# False 2157 MONDO:0004377
# False 2158 MONDO:0004378
# False 2159 MONDO:0004380
# False 2160 MONDO:0004381
# False 2161 MONDO:0004383
# False 2162 MONDO:0004384
# False 2163 MONDO:0004385
# False 2164 MONDO:0004386
# False 2165 MONDO:0004387
# False 2166 MONDO:0004389
# False 2167 MONDO:0004392
# False 2168 MONDO:0004393
# False 2169 MONDO:0004394
# False 2170 MONDO:0004396
# False 2171 MONDO:0004397
# False 2172 MONDO:0004398
# False 2173 MONDO:0004400
# False 2174 MONDO:0004401
# False 2175 MONDO:0004402
# False 2176 MONDO:0004404
# False 2177 MONDO:0004405
# False 2178 MONDO:0004406
# False 2179 MONDO:0004407
# False 2180 MONDO:0004408
# False 2181 MONDO:0004409
# False 2182 MONDO:0004410
# False 2183 MONDO:0004411
# False 2184 MONDO:0004412
# False 2185 MONDO:0004413
# False 2186 MONDO:0004414
# False 2187 MONDO:0004415
# False 2188 MONDO:0004416
# False 2189 MONDO:0004417
# False 2190 MONDO:0004418
# False 2191 MONDO:0004419
# False 2192 MONDO:0004420
# False 2193 MONDO:0004421
# False 2194 MONDO:0004422
# False 2195 MONDO:0004423
# False 2196 MONDO:0004426
# False 2197 MONDO:0004427
# False 2198 MONDO:0004428
# False 2199 MONDO:0004429
# False 2200 MONDO:0004430
# False 2201 MONDO:0004431
# False 2202 MONDO:0004432
# False 2203 MONDO:0004433
# False 2204 MONDO:0004435
# False 2205 MONDO:0004436
# False 2206 MONDO:0004438
# False 2207 MONDO:0004439
# False 2208 MONDO:0004440
# False 2209 MONDO:0004441
# False 2210 MONDO:0004442
# False 2211 MONDO:0004443
# False 2212 MONDO:0004444
# False 2213 MONDO:0004445
# False 2214 MONDO:0004446
# False 2215 MONDO:0004447
# False 2216 MONDO:0004448
# False 2217 MONDO:0004449
# False 2218 MONDO:0004450
# False 2219 MONDO:0004451
# False 2220 MONDO:0004452
# False 2221 MONDO:0004453
# False 2222 MONDO:0004454
# False 2223 MONDO:0004455
# False 2224 MONDO:0004456
# False 2225 MONDO:0004457
# False 2226 MONDO:0002840
# False 2227 MONDO:0002842
# False 2228 MONDO:0002843
# False 2229 MONDO:0002844
# False 2230 MONDO:0002845
# False 2231 MONDO:0002846
# False 2232 MONDO:0002847
# False 2233 MONDO:0002848
# False 2234 MONDO:0002849
# False 2235 MONDO:0002850
# False 2236 MONDO:0002851
# False 2237 MONDO:0002852
# False 2238 MONDO:0002853
# False 2239 MONDO:0002854
# False 2240 MONDO:0002855
# False 2241 MONDO:0002856
# False 2242 MONDO:0002857
# False 2243 MONDO:0002858
# False 2244 MONDO:0002859
# False 2245 MONDO:0002860
# False 2246 MONDO:0002861
# False 2247 MONDO:0002862
# False 2248 MONDO:0002863
# False 2249 MONDO:0002864
# False 2250 MONDO:0002865
# False 2251 MONDO:0002866
# False 2252 MONDO:0002867
# False 2253 MONDO:0002868
# False 2254 MONDO:0002870
# False 2255 MONDO:0002871
# False 2256 MONDO:0002872
# False 2257 MONDO:0002874
# False 2258 MONDO:0002876
# False 2259 MONDO:0002877
# False 2260 MONDO:0002878
# False 2261 MONDO:0002879
# False 2262 MONDO:0002880
# False 2263 MONDO:0002881
# False 2264 MONDO:0002882
# False 2265 MONDO:0002883
# False 2266 MONDO:0002884
# False 2267 MONDO:0002885
# False 2268 MONDO:0002886
# False 2269 MONDO:0002887
# False 2270 MONDO:0002888
# False 2271 MONDO:0002889
# False 2272 MONDO:0002892
# False 2273 MONDO:0002896
# False 2274 MONDO:0002897
# False 2275 MONDO:0002899
# False 2276 MONDO:0002900
# False 2277 MONDO:0002901
# False 2278 MONDO:0002904
# False 2279 MONDO:0002907
# False 2280 MONDO:0002910
# False 2281 MONDO:0002911
# False 2282 MONDO:0002913
# False 2283 MONDO:0002914
# False 2284 MONDO:0002915
# False 2285 MONDO:0002916
# False 2286 MONDO:0002918
# False 2287 MONDO:0002919
# False 2288 MONDO:0002920
# False 2289 MONDO:0002921
# False 2290 MONDO:0002923
# False 2291 MONDO:0002924
# False 2292 MONDO:0002926
# False 2293 MONDO:0002927
# False 2294 MONDO:0002928
# False 2295 MONDO:0002929
# False 2296 MONDO:0002930
# False 2297 MONDO:0002931
# False 2298 MONDO:0002934
# False 2299 MONDO:0002935
# False 2300 MONDO:0002936
# False 2301 MONDO:0002937
# False 2302 MONDO:0002938
# False 2303 MONDO:0002939
# False 2304 MONDO:0002940
# False 2305 MONDO:0002942
# False 2306 MONDO:0002943
# False 2307 MONDO:0002944
# False 2308 MONDO:0002945
# False 2309 MONDO:0002946
# False 2310 MONDO:0002947
# False 2311 MONDO:0002948
# False 2312 MONDO:0002949
# False 2313 MONDO:0002950
# False 2314 MONDO:0002951
# False 2315 MONDO:0002952
# False 2316 MONDO:0002953
# False 2317 MONDO:0002954
# False 2318 MONDO:0002955
# False 2319 MONDO:0002956
# False 2320 MONDO:0002957
# False 2321 MONDO:0002958
# False 2322 MONDO:0002959
# False 2323 MONDO:0002960
# False 2324 MONDO:0002961
# False 2325 MONDO:0002962
# False 2326 MONDO:0003751
# False 2327 MONDO:0003752
# False 2328 MONDO:0003753
# False 2329 MONDO:0003754
# False 2330 MONDO:0003755
# False 2331 MONDO:0003756
# False 2332 MONDO:0003757
# False 2333 MONDO:0003758
# False 2334 MONDO:0003759
# False 2335 MONDO:0003760
# False 2336 MONDO:0003761
# False 2337 MONDO:0003762
# False 2338 MONDO:0003763
# False 2339 MONDO:0003764
# False 2340 MONDO:0003765
# False 2341 MONDO:0003766
# False 2342 MONDO:0003768
# False 2343 MONDO:0003769
# False 2344 MONDO:0003770
# False 2345 MONDO:0003771
# False 2346 MONDO:0003772
# False 2347 MONDO:0003773
# False 2348 MONDO:0003774
# False 2349 MONDO:0003775
# False 2350 MONDO:0003776
# False 2351 MONDO:0003777
# False 2352 MONDO:0003781
# False 2353 MONDO:0003782
# False 2354 MONDO:0003783
# False 2355 MONDO:0003784
# False 2356 MONDO:0003786
# False 2357 MONDO:0003787
# False 2358 MONDO:0003788
# False 2359 MONDO:0003789
# False 2360 MONDO:0003790
# False 2361 MONDO:0003791
# False 2362 MONDO:0003792
# False 2363 MONDO:0003795
# False 2364 MONDO:0003796
# False 2365 MONDO:0003800
# False 2366 MONDO:0003801
# False 2367 MONDO:0003802
# False 2368 MONDO:0003803
# False 2369 MONDO:0003805
# False 2370 MONDO:0003806
# False 2371 MONDO:0003808
# False 2372 MONDO:0003809
# False 2373 MONDO:0003810
# False 2374 MONDO:0003811
# False 2375 MONDO:0003812
# False 2376 MONDO:0003813
# False 2377 MONDO:0003816
# False 2378 MONDO:0003818
# False 2379 MONDO:0003819
# False 2380 MONDO:0003820
# False 2381 MONDO:0003821
# False 2382 MONDO:0003822
# False 2383 MONDO:0003824
# False 2384 MONDO:0003825
# False 2385 MONDO:0003826
# False 2386 MONDO:0003827
# False 2387 MONDO:0003828
# False 2388 MONDO:0003829
# False 2389 MONDO:0003830
# False 2390 MONDO:0003831
# False 2391 MONDO:0003834
# False 2392 MONDO:0003835
# False 2393 MONDO:0003836
# False 2394 MONDO:0003837
# False 2395 MONDO:0003839
# False 2396 MONDO:0003840
# False 2397 MONDO:0003841
# False 2398 MONDO:0003842
# False 2399 MONDO:0003843
# False 2400 MONDO:0003844
# False 2401 MONDO:0003845
# False 2402 MONDO:0003846
# False 2403 MONDO:0003848
# False 2404 MONDO:0003849
# False 2405 MONDO:0003850
# False 2406 MONDO:0003851
# False 2407 MONDO:0003852
# False 2408 MONDO:0003853
# False 2409 MONDO:0003856
# False 2410 MONDO:0003857
# False 2411 MONDO:0003858
# False 2412 MONDO:0003859
# False 2413 MONDO:0003860
# False 2414 MONDO:0003861
# False 2415 MONDO:0003862
# False 2416 MONDO:0003863
# False 2417 MONDO:0003864
# False 2418 MONDO:0003865
# False 2419 MONDO:0003866
# False 2420 MONDO:0003867
# False 2421 MONDO:0003868
# False 2422 MONDO:0003869
# False 2423 MONDO:0003870
# False 2424 MONDO:0003872
# False 2425 MONDO:0003873
# False 2426 MONDO:0020162
# False 2427 MONDO:0020242
# False 2428 MONDO:0020247
# False 2429 MONDO:0001746
# False 2430 MONDO:0001747
# False 2431 MONDO:0001748
# False 2432 MONDO:0001749
# False 2433 MONDO:0001751
# False 2434 MONDO:0001752
# False 2435 MONDO:0001753
# False 2436 MONDO:0001754
# False 2437 MONDO:0001756
# False 2438 MONDO:0001757
# False 2439 MONDO:0001758
# False 2440 MONDO:0001760
# False 2441 MONDO:0001761
# False 2442 MONDO:0001762
# False 2443 MONDO:0001763
# False 2444 MONDO:0001764
# False 2445 MONDO:0001765
# False 2446 MONDO:0001766
# False 2447 MONDO:0001767
# False 2448 MONDO:0001768
# False 2449 MONDO:0001769
# False 2450 MONDO:0001770
# False 2451 MONDO:0001771
# False 2452 MONDO:0001772
# False 2453 MONDO:0001773
# False 2454 MONDO:0001774
# False 2455 MONDO:0001775
# False 2456 MONDO:0001776
# False 2457 MONDO:0001777
# False 2458 MONDO:0001778
# False 2459 MONDO:0001779
# False 2460 MONDO:0001780
# False 2461 MONDO:0001781
# False 2462 MONDO:0001782
# False 2463 MONDO:0001783
# False 2464 MONDO:0001784
# False 2465 MONDO:0001785
# False 2466 MONDO:0001786
# False 2467 MONDO:0001787
# False 2468 MONDO:0001788
# False 2469 MONDO:0001789
# False 2470 MONDO:0001790
# False 2471 MONDO:0001791
# False 2472 MONDO:0001792
# False 2473 MONDO:0001793
# False 2474 MONDO:0001794
# False 2475 MONDO:0001795
# False 2476 MONDO:0001797
# False 2477 MONDO:0001798
# False 2478 MONDO:0001799
# False 2479 MONDO:0001800
# False 2480 MONDO:0001801
# False 2481 MONDO:0001802
# False 2482 MONDO:0001803
# False 2483 MONDO:0001804
# False 2484 MONDO:0001805
# False 2485 MONDO:0001806
# False 2486 MONDO:0001808
# False 2487 MONDO:0001809
# False 2488 MONDO:0001810
# False 2489 MONDO:0001811
# False 2490 MONDO:0001812
# False 2491 MONDO:0001813
# False 2492 MONDO:0001815
# False 2493 MONDO:0001816
# False 2494 MONDO:0001817
# False 2495 MONDO:0001818
# False 2496 MONDO:0001819
# False 2497 MONDO:0001820
# False 2498 MONDO:0001821
# False 2499 MONDO:0001822
# False 2500 MONDO:0001823
# False 2501 MONDO:0001827
# False 2502 MONDO:0001828
# False 2503 MONDO:0001830
# False 2504 MONDO:0001831
# False 2505 MONDO:0001832
# False 2506 MONDO:0001833
# False 2507 MONDO:0001834
# False 2508 MONDO:0001836
# False 2509 MONDO:0001837
# False 2510 MONDO:0001838
# False 2511 MONDO:0001841
# False 2512 MONDO:0001842
# False 2513 MONDO:0001843
# False 2514 MONDO:0001844
# False 2515 MONDO:0001845
# False 2516 MONDO:0001846
# False 2517 MONDO:0001847
# False 2518 MONDO:0001848
# False 2519 MONDO:0001850
# False 2520 MONDO:0001851
# False 2521 MONDO:0001852
# False 2522 MONDO:0001853
# False 2523 MONDO:0001855
# False 2524 MONDO:0001856
# False 2525 MONDO:0001857
# False 2526 MONDO:0001490
# False 2527 MONDO:0001491
# False 2528 MONDO:0001492
# False 2529 MONDO:0001493
# False 2530 MONDO:0001495
# False 2531 MONDO:0001496
# False 2532 MONDO:0001497
# False 2533 MONDO:0001498
# False 2534 MONDO:0001499
# False 2535 MONDO:0001500
# False 2536 MONDO:0001501
# False 2537 MONDO:0001502
# False 2538 MONDO:0001503
# False 2539 MONDO:0001504
# False 2540 MONDO:0001505
# False 2541 MONDO:0001506
# False 2542 MONDO:0001507
# False 2543 MONDO:0001508
# False 2544 MONDO:0001509
# False 2545 MONDO:0001510
# False 2546 MONDO:0001511
# False 2547 MONDO:0001512
# False 2548 MONDO:0001513
# False 2549 MONDO:0001514
# False 2550 MONDO:0001515
# False 2551 MONDO:0001516
# False 2552 MONDO:0001517
# False 2553 MONDO:0001518
# False 2554 MONDO:0001519
# False 2555 MONDO:0001520
# False 2556 MONDO:0001521
# False 2557 MONDO:0001522
# False 2558 MONDO:0001523
# False 2559 MONDO:0001525
# False 2560 MONDO:0001526
# False 2561 MONDO:0001527
# False 2562 MONDO:0001528
# False 2563 MONDO:0001529
# False 2564 MONDO:0001530
# False 2565 MONDO:0001531
# False 2566 MONDO:0001532
# False 2567 MONDO:0001533
# False 2568 MONDO:0001534
# False 2569 MONDO:0001535
# False 2570 MONDO:0001536
# False 2571 MONDO:0001537
# False 2572 MONDO:0001538
# False 2573 MONDO:0001539
# False 2574 MONDO:0001540
# False 2575 MONDO:0001541
# False 2576 MONDO:0001542
# False 2577 MONDO:0001543
# False 2578 MONDO:0001544
# False 2579 MONDO:0001546
# False 2580 MONDO:0001547
# False 2581 MONDO:0001548
# False 2582 MONDO:0001549
# False 2583 MONDO:0001551
# False 2584 MONDO:0001552
# False 2585 MONDO:0001553
# False 2586 MONDO:0001554
# False 2587 MONDO:0001555
# False 2588 MONDO:0001556
# False 2589 MONDO:0001557
# False 2590 MONDO:0001558
# False 2591 MONDO:0001559
# False 2592 MONDO:0001560
# False 2593 MONDO:0001561
# False 2594 MONDO:0001562
# False 2595 MONDO:0001563
# False 2596 MONDO:0001564
# False 2597 MONDO:0001565
# False 2598 MONDO:0001566
# False 2599 MONDO:0001567
# False 2600 MONDO:0001568
# False 2601 MONDO:0001569
# False 2602 MONDO:0001571
# False 2603 MONDO:0001572
# False 2604 MONDO:0001574
# False 2605 MONDO:0001575
# False 2606 MONDO:0001576
# False 2607 MONDO:0001577
# False 2608 MONDO:0001579
# False 2609 MONDO:0001580
# False 2610 MONDO:0001582
# False 2611 MONDO:0001583
# False 2612 MONDO:0001584
# False 2613 MONDO:0001585
# False 2614 MONDO:0001586
# False 2615 MONDO:0001588
# False 2616 MONDO:0001590
# False 2617 MONDO:0001591
# False 2618 MONDO:0001592
# False 2619 MONDO:0001593
# False 2620 MONDO:0001594
# False 2621 MONDO:0001595
# False 2622 MONDO:0001596
# False 2623 MONDO:0001597
# False 2624 MONDO:0001598
# False 2625 MONDO:0001600
# False 2626 MONDO:0017307
# False 2627 MONDO:0017314
# False 2628 MONDO:0017341
# False 2629 MONDO:0017343
# False 2630 MONDO:0017345
# False 2631 MONDO:0017386
# False 2632 MONDO:0017387
# False 2633 MONDO:0017582
# False 2634 MONDO:0017588
# False 2635 MONDO:0017590
# False 2636 MONDO:0017594
# False 2637 MONDO:0017611
# False 2638 MONDO:0017703
# False 2639 MONDO:0017742
# False 2640 MONDO:0017755
# False 2641 MONDO:0017763
# False 2642 MONDO:0017767
# False 2643 MONDO:0017827
# False 2644 MONDO:0017884
# False 2645 MONDO:0017885
# False 2646 MONDO:0017891
# False 2647 MONDO:0018053
# False 2648 MONDO:0018079
# False 2649 MONDO:0018087
# False 2650 MONDO:0018093
# False 2651 MONDO:0018171
# False 2652 MONDO:0018172
# False 2653 MONDO:0018187
# False 2654 MONDO:0018191
# False 2655 MONDO:0018201
# False 2656 MONDO:0018270
# ...
# False 21891 MONDO:0025506
# False 21892 MONDO:0025510
# False 21893 MONDO:0025512
# False 21894 MONDO:0025513
# False 21895 MONDO:0025514
# False 21896 MONDO:0025556
# False 21897 MONDO:0025598
# False 21898 MONDO:0025622
# False 21899 MONDO:0025667
# False 21900 MONDO:0025690
# False 21901 MONDO:0025691
# False 21902 MONDO:0025699
# False 21903 MONDO:0025701
# False 21904 MONDO:0025708
# False 21905 MONDO:0025712
# False 21906 MONDO:0044797
# False 21907 MONDO:0044800
# False 21908 MONDO:0044811
# False 21909 MONDO:0044816
# False 21910 MONDO:0044817
# False 21911 MONDO:0044843
# False 21912 MONDO:0044870
# False 21913 MONDO:0044871
# False 21914 MONDO:0044872
# False 21915 MONDO:0044873
# False 21916 MONDO:0044874
# False 21917 MONDO:0044875
# False 21918 MONDO:0044876
# False 21919 MONDO:0044877
# False 21920 MONDO:0044879
# False 21921 MONDO:0044880
# False 21922 MONDO:0044884
# False 21923 MONDO:0044885
# False 21924 MONDO:0044889
# False 21925 MONDO:0044903
# False 21926 MONDO:0044907
# False 21927 MONDO:0044912
# False 21928 MONDO:0044913
# False 21929 MONDO:0044915
# False 21930 MONDO:0044916
# False 21931 MONDO:0044917
# False 21932 MONDO:0044921
# False 21933 MONDO:0044923
# False 21934 MONDO:0044926
# False 21935 MONDO:0044956
# False 21936 MONDO:0044981
# False 21937 MONDO:0044982
# False 21938 MONDO:0044995
# False 21939 MONDO:0044997
# False 21940 MONDO:0045008
# False 21941 MONDO:0045010
# False 21942 MONDO:0045015
# False 21943 MONDO:0045023
# False 21944 MONDO:0045034
# False 21945 MONDO:0045037
# False 21946 MONDO:0045038
# False 21947 MONDO:0045039
# False 21948 MONDO:0045040
# False 21949 MONDO:0045053
# False 21950 MONDO:0045059
# False 21951 MONDO:0045060
# False 21952 MONDO:0045068
# False 21953 MONDO:0049221
# False 21954 MONDO:0049222
# False 21955 MONDO:0049223
# False 21956 MONDO:0054549
# False 21957 MONDO:0054550
# False 21958 MONDO:0054551
# False 21959 MONDO:0054559
# False 21960 MONDO:0054560
# False 21961 MONDO:0054561
# False 21962 MONDO:0054565
# False 21963 MONDO:0054573
# False 21964 MONDO:0054577
# False 21965 MONDO:0054581
# False 21966 MONDO:0054582
# False 21967 MONDO:0054588
# False 21968 MONDO:0054591
# False 21969 MONDO:0054593
# False 21970 MONDO:0054601
# False 21971 MONDO:0054602
# False 21972 MONDO:0054615
# False 21973 MONDO:0054636
# False 21974 MONDO:0054637
# False 21975 MONDO:0054654
# False 21976 MONDO:0054665
# False 21977 MONDO:0054666
# False 21978 MONDO:0054669
# False 21979 MONDO:0054677
# False 21980 MONDO:0054680
# False 21981 MONDO:0054691
# False 21982 MONDO:0054695
# False 21983 MONDO:0054696
# False 21984 MONDO:0054697
# False 21985 MONDO:0054698
# False 21986 MONDO:0054699
# False 21987 MONDO:0054700
# False 21988 MONDO:0054701
# False 21989 MONDO:0054708
# False 21990 MONDO:0054716
# False 21991 MONDO:0054722
# False 21992 MONDO:0054723
# False 21993 MONDO:0054724
# False 21994 MONDO:0054725
# False 21995 MONDO:0054726
# False 21996 MONDO:0054727
# False 21997 MONDO:0054728
# False 21998 MONDO:0054729
# False 21999 MONDO:0054730
# False 22000 MONDO:0054731
# False 22001 MONDO:0054732
# False 22002 MONDO:0054733
# False 22003 MONDO:0054736
# False 22004 MONDO:0054737
# False 22005 MONDO:0054738
# False 22006 MONDO:0030732
# False 22007 MONDO:0030733
# False 22008 MONDO:0030736
# False 22009 MONDO:0030746
# False 22010 MONDO:0030747
# False 22011 MONDO:0030748
# False 22012 MONDO:0030749
# False 22013 MONDO:0030750
# False 22014 MONDO:0030756
# False 22015 MONDO:0030768
# False 22016 MONDO:0030770
# False 22017 MONDO:0030781
# False 22018 MONDO:0030785
# False 22019 MONDO:0030787
# False 22020 MONDO:0030796
# False 22021 MONDO:0030797
# False 22022 MONDO:0030798
# False 22023 MONDO:0030800
# False 22024 MONDO:0030801
# False 22025 MONDO:0030809
# False 22026 MONDO:0030810
# False 22027 MONDO:0030813
# False 22028 MONDO:0030815
# False 22029 MONDO:0030818
# False 22030 MONDO:0030819
# False 22031 MONDO:0030822
# False 22032 MONDO:0030827
# False 22033 MONDO:0030831
# False 22034 MONDO:0030835
# False 22035 MONDO:0030837
# False 22036 MONDO:0030839
# False 22037 MONDO:0030840
# False 22038 MONDO:0030841
# False 22039 MONDO:0030843
# False 22040 MONDO:0030844
# False 22041 MONDO:0030846
# False 22042 MONDO:0030847
# False 22043 MONDO:0030849
# False 22044 MONDO:0030852
# False 22045 MONDO:0030854
# False 22046 MONDO:0030855
# False 22047 MONDO:0030856
# False 22048 MONDO:0030858
# False 22049 MONDO:0030859
# False 22050 MONDO:0030860
# False 22051 MONDO:0030861
# False 22052 MONDO:0030862
# False 22053 MONDO:0030864
# False 22054 MONDO:0030866
# False 22055 MONDO:0030867
# False 22056 MONDO:0030868
# False 22057 MONDO:0030869
# False 22058 MONDO:0030870
# False 22059 MONDO:0030871
# False 22060 MONDO:0030872
# False 22061 MONDO:0030873
# False 22062 MONDO:0030875
# False 22063 MONDO:0030876
# False 22064 MONDO:0030877
# False 22065 MONDO:0030878
# False 22066 MONDO:0030880
# False 22067 MONDO:0030881
# False 22068 MONDO:0030883
# False 22069 MONDO:0030885
# False 22070 MONDO:0030886
# False 22071 MONDO:0030887
# False 22072 MONDO:0030890
# False 22073 MONDO:0030891
# False 22074 MONDO:0030893
# False 22075 MONDO:0030894
# False 22076 MONDO:0030895
# False 22077 MONDO:0030896
# False 22078 MONDO:0030897
# False 22079 MONDO:0030898
# False 22080 MONDO:0030899
# False 22081 MONDO:0030900
# False 22082 MONDO:0030902
# False 22083 MONDO:0030903
# False 22084 MONDO:0030905
# False 22085 MONDO:0030906
# False 22086 MONDO:0030907
# False 22087 MONDO:0030908
# False 22088 MONDO:0030909
# False 22089 MONDO:0030910
# False 22090 MONDO:0030911
# False 22091 MONDO:0030912
# False 22092 MONDO:0030913
# False 22093 MONDO:0030914
# False 22094 MONDO:0030915
# False 22095 MONDO:0030916
# False 22096 MONDO:0030917
# False 22097 MONDO:0030918
# False 22098 MONDO:0030919
# False 22099 MONDO:0030920
# False 22100 MONDO:0030921
# False 22101 MONDO:0030922
# False 22102 MONDO:0030924
# False 22103 MONDO:0030925
# False 22104 MONDO:0030926
# False 22105 MONDO:0030927
# False 22106 MONDO:0100079
# False 22107 MONDO:0100082
# False 22108 MONDO:0100083
# False 22109 MONDO:0100085
# False 22110 MONDO:0100090
# False 22111 MONDO:0100092
# False 22112 MONDO:0100093
# False 22113 MONDO:0100094
# False 22114 MONDO:0100095
# False 22115 MONDO:0100096
# False 22116 MONDO:0100097
# False 22117 MONDO:0100099
# False 22118 MONDO:0100101
# False 22119 MONDO:0100102
# False 22120 MONDO:0100103
# False 22121 MONDO:0100104
# False 22122 MONDO:0100105
# False 22123 MONDO:0100107
# False 22124 MONDO:0100109
# False 22125 MONDO:0100110
# False 22126 MONDO:0100111
# False 22127 MONDO:0100112
# False 22128 MONDO:0100113
# False 22129 MONDO:0100114
# False 22130 MONDO:0100115
# False 22131 MONDO:0100116
# False 22132 MONDO:0100125
# False 22133 MONDO:0100128
# False 22134 MONDO:0100129
# False 22135 MONDO:0100130
# False 22136 MONDO:0100131
# False 22137 MONDO:0100132
# False 22138 MONDO:0100133
# False 22139 MONDO:0100134
# False 22140 MONDO:0100138
# False 22141 MONDO:0100144
# False 22142 MONDO:0100156
# False 22143 MONDO:0100157
# False 22144 MONDO:0100160
# False 22145 MONDO:0100161
# False 22146 MONDO:0100163
# False 22147 MONDO:0100164
# False 22148 MONDO:0100165
# False 22149 MONDO:0100175
# False 22150 MONDO:0100176
# False 22151 MONDO:0100185
# False 22152 MONDO:0100186
# False 22153 MONDO:0100188
# False 22154 MONDO:0100192
# False 22155 MONDO:0100193
# False 22156 MONDO:0100194
# False 22157 MONDO:0100197
# False 22158 MONDO:0100203
# False 22159 MONDO:0100204
# False 22160 MONDO:0100205
# False 22161 MONDO:0100209
# False 22162 MONDO:0100210
# False 22163 MONDO:0100211
# False 22164 MONDO:0100212
# False 22165 MONDO:0100213
# False 22166 MONDO:0100214
# False 22167 MONDO:0100215
# False 22168 MONDO:0100218
# False 22169 MONDO:0100219
# False 22170 MONDO:0100220
# False 22171 MONDO:0100221
# False 22172 MONDO:0100222
# False 22173 MONDO:0100223
# False 22174 MONDO:0100224
# False 22175 MONDO:0100226
# False 22176 MONDO:0100230
# False 22177 MONDO:0100231
# False 22178 MONDO:0100232
# False 22179 MONDO:0100233
# False 22180 MONDO:0100248
# False 22181 MONDO:0100250
# False 22182 MONDO:0100251
# False 22183 MONDO:0100252
# False 22184 MONDO:0100255
# False 22185 MONDO:0100257
# False 22186 MONDO:0100276
# False 22187 MONDO:0100277
# False 22188 MONDO:0100281
# False 22189 MONDO:0100282
# False 22190 MONDO:0100284
# False 22191 MONDO:0100285
# False 22192 MONDO:0100286
# False 22193 MONDO:0100288
# False 22194 MONDO:0100289
# False 22195 MONDO:0100290
# False 22196 MONDO:0100291
# False 22197 MONDO:0100294
# False 22198 MONDO:0100296
# False 22199 MONDO:0100297
# False 22200 MONDO:0100304
# False 22201 MONDO:0100305
# False 22202 MONDO:0100307
# False 22203 MONDO:0100312
# False 22204 MONDO:0100315
# False 22205 MONDO:0100316
# False 22206 MONDO:0020557
# False 22207 MONDO:0020558
# False 22208 MONDO:0020559
# False 22209 MONDO:0020562
# False 22210 MONDO:0020563
# False 22211 MONDO:0020567
# False 22212 MONDO:0020569
# False 22213 MONDO:0020571
# False 22214 MONDO:0020572
# False 22215 MONDO:0020575
# False 22216 MONDO:0020582
# False 22217 MONDO:0020584
# False 22218 MONDO:0020597
# False 22219 MONDO:0020599
# False 22220 MONDO:0020600
# False 22221 MONDO:0020602
# False 22222 MONDO:0020603
# False 22223 MONDO:0020607
# False 22224 MONDO:0020627
# False 22225 MONDO:0020628
# False 22226 MONDO:0020630
# False 22227 MONDO:0020631
# False 22228 MONDO:0020632
# False 22229 MONDO:0020634
# False 22230 MONDO:0020635
# False 22231 MONDO:0020636
# False 22232 MONDO:0020637
# False 22233 MONDO:0020638
# False 22234 MONDO:0020639
# False 22235 MONDO:0020640
# False 22236 MONDO:0020643
# False 22237 MONDO:0020646
# False 22238 MONDO:0020647
# False 22239 MONDO:0020648
# False 22240 MONDO:0020649
# False 22241 MONDO:0020650
# False 22242 MONDO:0020651
# False 22243 MONDO:0020652
# False 22244 MONDO:0020655
# False 22245 MONDO:0020657
# False 22246 MONDO:0020658
# False 22247 MONDO:0020659
# False 22248 MONDO:0020660
# False 22249 MONDO:0020661
# False 22250 MONDO:0020662
# False 22251 MONDO:0020666
# False 22252 MONDO:0020667
# False 22253 MONDO:0020677
# False 22254 MONDO:0020679
# False 22255 MONDO:0020680
# False 22256 MONDO:0020681
# False 22257 MONDO:0020682
# False 22258 MONDO:0020684
# False 22259 MONDO:0020686
# False 22260 MONDO:0020688
# False 22261 MONDO:0020689
# False 22262 MONDO:0020692
# False 22263 MONDO:0020694
# False 22264 MONDO:0020695
# False 22265 MONDO:0020697
# False 22266 MONDO:0020701
# False 22267 MONDO:0020705
# False 22268 MONDO:0020706
# False 22269 MONDO:0020707
# False 22270 MONDO:0020708
# False 22271 MONDO:0020709
# False 22272 MONDO:0020710
# False 22273 MONDO:0020711
# False 22274 MONDO:0020712
# False 22275 MONDO:0020713
# False 22276 MONDO:0020714
# False 22277 MONDO:0020715
# False 22278 MONDO:0020716
# False 22279 MONDO:0020717
# False 22280 MONDO:0020718
# False 22281 MONDO:0020722
# False 22282 MONDO:0020723
# False 22283 MONDO:0020724
# False 22284 MONDO:0020725
# False 22285 MONDO:0020726
# False 22286 MONDO:0020728
# False 22287 MONDO:0020729
# False 22288 MONDO:0020730
# False 22289 MONDO:0020731
# False 22290 MONDO:0020733
# False 22291 MONDO:0020735
# False 22292 MONDO:0020736
# False 22293 MONDO:0020737
# False 22294 MONDO:0020738
# False 22295 MONDO:0020739
# False 22296 MONDO:0020740
# False 22297 MONDO:0020741
# False 22298 MONDO:0020743
# False 22299 MONDO:0020744
# False 22300 MONDO:0020745
# False 22301 MONDO:0020746
# False 22302 MONDO:0020747
# False 22303 MONDO:0020748
# False 22304 MONDO:0020749
# False 22305 MONDO:0020750
# False 22306 MONDO:0700100
# False 22307 MONDO:0700101
# False 22308 MONDO:0700106
# False 22309 MONDO:0700107
# False 22310 MONDO:0700109
# False 22311 MONDO:0700111
# False 22312 MONDO:0700112
# False 22313 MONDO:0700118
# False 22314 MONDO:0700119
# False 22315 MONDO:0700121
# False 22316 MONDO:0700122
# False 22317 MONDO:0700123
# False 22318 MONDO:0700126
# False 22319 MONDO:0700127
# False 22320 MONDO:0700128
# False 22321 MONDO:0700129
# False 22322 MONDO:0700130
# False 22323 MONDO:0700131
# False 22324 MONDO:0700132
# False 22325 MONDO:0700133
# False 22326 MONDO:0700134
# False 22327 MONDO:0700135
# False 22328 MONDO:0700136
# False 22329 MONDO:0700137
# False 22330 MONDO:0700138
# False 22331 MONDO:0700139
# False 22332 MONDO:0700140
# False 22333 MONDO:0700141
# False 22334 MONDO:0700142
# False 22335 MONDO:0700143
# False 22336 MONDO:0700144
# False 22337 MONDO:0700145
# False 22338 MONDO:0700146
# False 22339 MONDO:0700147
# False 22340 MONDO:0700148
# False 22341 MONDO:0700149
# False 22342 MONDO:0700150
# False 22343 MONDO:0700151
# False 22344 MONDO:0700152
# False 22345 MONDO:0700153
# False 22346 MONDO:0700154
# False 22347 MONDO:0700155
# False 22348 MONDO:0700156
# False 22349 MONDO:0700157
# False 22350 MONDO:0700158
# False 22351 MONDO:0700159
# False 22352 MONDO:0700160
# False 22353 MONDO:0700161
# False 22354 MONDO:0700162
# False 22355 MONDO:0700163
# False 22356 MONDO:0700164
# False 22357 MONDO:0700165
# False 22358 MONDO:0700166
# False 22359 MONDO:0700167
# False 22360 MONDO:0700168
# False 22361 MONDO:0700169
# False 22362 MONDO:0700171
# False 22363 MONDO:0700172
# False 22364 MONDO:0700173
# False 22365 MONDO:0700174
# False 22366 MONDO:0700175
# False 22367 MONDO:0700176
# False 22368 MONDO:0700177
# False 22369 MONDO:0700178
# False 22370 MONDO:0700179
# False 22371 MONDO:0700180
# False 22372 MONDO:0700181
# False 22373 MONDO:0700182
# False 22374 MONDO:0700183
# False 22375 MONDO:0700184
# False 22376 MONDO:0700185
# False 22377 MONDO:0700186
# False 22378 MONDO:0700187
# False 22379 MONDO:0700188
# False 22380 MONDO:0700189
# False 22381 MONDO:0700190
# False 22382 MONDO:0700191
# False 22383 MONDO:0700192
# False 22384 MONDO:0700193
# False 22385 MONDO:0700194
# False 22386 MONDO:0700195
# False 22387 MONDO:0700196
# False 22388 MONDO:0700197
# False 22389 MONDO:0700198
# False 22390 MONDO:0700199
# False 22391 MONDO:0800001
# False 22392 MONDO:0800025
# False 22393 MONDO:0800026
# False 22394 MONDO:0800027
# False 22395 MONDO:0800028
# False 22396 MONDO:0800029
# False 22397 MONDO:0800030
# False 22398 MONDO:0800031
# False 22399 MONDO:0800032
# False 22400 MONDO:0800033
# False 22401 MONDO:0800034
# False 22402 MONDO:0800035
# False 22403 MONDO:0800036
# False 22404 MONDO:0800037
# False 22405 MONDO:0800038
# False 22406 MONDO:0018877
# False 22407 MONDO:0018879
# False 22408 MONDO:0018884
# False 22409 MONDO:0018885
# False 22410 MONDO:0018890
# False 22411 MONDO:0018892
# False 22412 MONDO:0018893
# False 22413 MONDO:0018895
# False 22414 MONDO:0018897
# False 22415 MONDO:0018899
# False 22416 MONDO:0018900
# False 22417 MONDO:0018903
# False 22418 MONDO:0018913
# False 22419 MONDO:0018918
# False 22420 MONDO:0018919
# False 22421 MONDO:0018922
# False 22422 MONDO:0018927
# False 22423 MONDO:0018929
# False 22424 MONDO:0018930
# False 22425 MONDO:0018931
# False 22426 MONDO:0018932
# False 22427 MONDO:0018933
# False 22428 MONDO:0018936
# False 22429 MONDO:0018941
# False 22430 MONDO:0018942
# False 22431 MONDO:0018945
# False 22432 MONDO:0018946
# False 22433 MONDO:0018951
# False 22434 MONDO:0018952
# False 22435 MONDO:0018955
# False 22436 MONDO:0018957
# False 22437 MONDO:0018959
# False 22438 MONDO:0018962
# False 22439 MONDO:0018967
# False 22440 MONDO:0018968
# False 22441 MONDO:0018969
# False 22442 MONDO:0018974
# False 22443 MONDO:0018976
# False 22444 MONDO:0018977
# False 22445 MONDO:0018978
# False 22446 MONDO:0018979
# False 22447 MONDO:0018980
# False 22448 MONDO:0018981
# False 22449 MONDO:0018983
# False 22450 MONDO:0018984
# False 22451 MONDO:0018987
# False 22452 MONDO:0018988
# False 22453 MONDO:0018989
# False 22454 MONDO:0018991
# False 22455 MONDO:0018992
# False 22456 MONDO:0019000
# False 22457 MONDO:0019002
# False 22458 MONDO:0019007
# False 22459 MONDO:0019013
# False 22460 MONDO:0019016
# False 22461 MONDO:0019017
# False 22462 MONDO:0019018
# False 22463 MONDO:0019020
# False 22464 MONDO:0019022
# False 22465 MONDO:0019023
# False 22466 MONDO:0019024
# False 22467 MONDO:0019025
# False 22468 MONDO:0019028
# False 22469 MONDO:0019029
# False 22470 MONDO:0019031
# False 22471 MONDO:0019032
# False 22472 MONDO:0019033
# False 22473 MONDO:0019034
# False 22474 MONDO:0019035
# False 22475 MONDO:0019036
# False 22476 MONDO:0019067
# False 22477 MONDO:0019068
# False 22478 MONDO:0019073
# False 22479 MONDO:0019074
# False 22480 MONDO:0019075
# False 22481 MONDO:0019076
# False 22482 MONDO:0019077
# False 22483 MONDO:0019082
# False 22484 MONDO:0019083
# False 22485 MONDO:0019084
# False 22486 MONDO:0019085
# False 22487 MONDO:0019088
# False 22488 MONDO:0019091
# False 22489 MONDO:0019092
# False 22490 MONDO:0019093
# False 22491 MONDO:0019094
# False 22492 MONDO:0019100
# False 22493 MONDO:0019101
# False 22494 MONDO:0019102
# False 22495 MONDO:0019103
# False 22496 MONDO:0019104
# False 22497 MONDO:0019105
# False 22498 MONDO:0019107
# False 22499 MONDO:0019108
# False 22500 MONDO:0019109
# False 22501 MONDO:0019112
# False 22502 MONDO:0019113
# False 22503 MONDO:0019114
# False 22504 MONDO:0019115
# False 22505 MONDO:0019120

# %%
arax_trapi_url = "https://arax.test.transltr.io/api/arax/v1.4"#
arax_trapi_url = "https://arax.ncats.io/api/arax/v1.3"

# %%
query = create_query(None,"MONDO:0015564")

# %%
post_query(arax_trapi_url,query)
# Out:
# Query is posted
# <Response [404]>
